# %% [markdown]
# ## Yelp Data: Support Vector Machines

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC, LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report

#suppress warnings
import sys
import warnings
import os

#Different attempts to suppress ConvergenceWarning when max_iter terminates
#before total model convergence
#https://stackoverflow.com/questions/53784971/how-to-disable-convergencewarning-using-sklearn
if not sys.warnoptions:
    warnings.simplefilter("ignore")
    os.environ["PYTHONWARNINGS"] = "ignore" # Also affect subprocesses

from sklearn.exceptions import ConvergenceWarning
ConvergenceWarning('ignore')

warnings.simplefilter("ignore", category=ConvergenceWarning)
warnings.filterwarnings('ignore')

# %%
#ALL PIPELINE CODE BELOW BY: Summer Long
#Added and modified print statements somewhat to fit into single cell

# run this just in case
#nltk.download('all')
nltk.download('stopwords')

# %% [markdown]
# ### Pre-process and run TF-IDF

# %%
#Summer Long code ct'd. 

# some models are tolerant of class imbalance
# also, the other dataset is now imbalanced due to category selection
# might as well use the naturally imbalanced one
yelp_data = pd.read_csv("yelp_true_sample_100k.csv")

def preprocess_text(text):
    # tokenizing test, ensuring it is not case insensitive
    tokens = nltk.word_tokenize(text.lower())
    
    # removing stop words
    stop_words = set(stopwords.words('english'))
    filtered_tokens = [token for token in tokens if token not in stop_words]
    
    # joining filtered tokens back into a string
    filtered_text = ' '.join(filtered_tokens)
    
    return filtered_text

# apply function to 'text' column in yelp_data
print("Pre-processing yelp data text...")
yelp_data['text'] = yelp_data['text'].apply(preprocess_text)

# create binary category based on star rating
print("Creating binary category based on star rating...")
yelp_data['sentiment'] = yelp_data['stars'].apply(lambda x: 0 if x <= 2 else 1)
print("Binary category complete")

#positive class rate
positive_class_rate = (yelp_data['sentiment'].sum()/100000) * 100
print(f"\nThe positive class rate is: {positive_class_rate}")

#negative class rate
negative_class_rate = 100 - (yelp_data['sentiment'].sum()/100000) * 100
print(f"The negative class rate is: {negative_class_rate}\n")

# Splitting into train/test with 80/20 split
TEST_SIZE = 0.2
print("Splitting into train and test data...")
print(f"Training data = {1 - TEST_SIZE}, test data = {TEST_SIZE}")
X_train, X_test, y_train, y_test = train_test_split(yelp_data['text'], 
                                                    yelp_data['sentiment'], 
                                                    test_size=TEST_SIZE, 
                                                    random_state=123)

print("Applying TF-IDF vectorizer to training data...")
# Define TF-IDF vectorizer and fit to the training data
tfidf_vectorizer = TfidfVectorizer()
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)

print("Applying TF-IDF vector to test data...")
# Transform testing data using the same vectorizer to prevent data leakage
X_test_tfidf = tfidf_vectorizer.transform(X_test)

print("Pipeline complete")
# Out:
# Pre-processing yelp data text...
# Creating binary category based on star rating...
# Binary category complete
#
# The positive class rate is: 76.912
# The negative class rate is: 23.087999999999994
#
# Splitting into train and test data...
# Training data = 0.8, test data = 0.2
# Applying TF-IDF vectorizer to training data...
# Applying TF-IDF vector to test data...
# Pipeline complete

# %%
#Checking size of the object

X_test_tfidf
# Out:
# <20000x65910 sparse matrix of type '<class 'numpy.float64'>'
# 	with 899405 stored elements in Compressed Sparse Row format>

# %%
#GRID SEARCH
#Implemented by: Matt Jackson
#Inspired heavily by and extremely indebted to: Summer Long
my_svc = SVC()

#define hyperparameters to tune via grid search
param_grid = {
    'C': [1.0, 0.1, 0.01],
    'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'max_iter': [100, 1000, 10000], #should probably go higher but that would
    #take prohibitively long, this scales at like O(n^3)
    'gamma': ['scale', 'auto']
}

grid_search = GridSearchCV(estimator=my_svc, param_grid=param_grid, 
                           cv=5, n_jobs=-1, verbose=2)

# Fit grid search to the training data
grid_search.fit(X_train_tfidf, y_train)

# Get best hyperparameters from the grid search
best_params = grid_search.best_params_

#RUNTIME: 5 hr 17 m 40 s
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] END ....C=1.0, gamma=scale, kernel=linear, max_iter=100; total time=   4.6s
# [CV] END ....C=1.0, gamma=scale, kernel=linear, max_iter=100; total time=   4.7s
# [CV] END ....C=1.0, gamma=scale, kernel=linear, max_iter=100; total time=   4.9s
# [CV] END ....C=1.0, gamma=scale, kernel=linear, max_iter=100; total time=   4.9s
# [CV] END ....C=1.0, gamma=scale, kernel=linear, max_iter=100; total time=   5.0s
# [CV] END ...C=1.0, gamma=scale, kernel=linear, max_iter=1000; total time=  53.3s
# [CV] END ...C=1.0, gamma=scale, kernel=linear, max_iter=1000; total time=  54.2s
# [CV] END ...C=1.0, gamma=scale, kernel=linear, max_iter=1000; total time=  54.2s
# [CV] END ...C=1.0, gamma=scale, kernel=linear, max_iter=1000; total time=  53.7s
# [CV] END ...C=1.0, gamma=scale, kernel=linear, max_iter=1000; total time=  54.0s
# [CV] END ......C=1.0, gamma=scale, kernel=poly, max_iter=100; total time=   5.5s
# [CV] END ......C=1.0, gamma=scale, kernel=poly, max_iter=100; total time=   5.4s
# [CV] END ......C=1.0, gamma=scale, kernel=poly, max_iter=100; total time=   5.2s
# [CV] END ......C=1.0, gamma=scale, kernel=poly, max_iter=100; total time=   5.5s
# [CV] END ......C=1.0, gamma=scale, kernel=poly, max_iter=100; total time=   5.7s
# [CV] END .....C=1.0, gamma=scale, kernel=poly, max_iter=1000; total time=  54.5s
# [CV] END .....C=1.0, gamma=scale, kernel=poly, max_iter=1000; total time=  54.9s
# [CV] END .....C=1.0, gamma=scale, kernel=poly, max_iter=1000; total time=  53.1s
# [CV] END .....C=1.0, gamma=scale, kernel=poly, max_iter=1000; total time=  54.6s
# [CV] END .....C=1.0, gamma=scale, kernel=poly, max_iter=1000; total time=  54.2s
# [CV] END ..C=1.0, gamma=scale, kernel=linear, max_iter=10000; total time= 7.9min
# [CV] END ..C=1.0, gamma=scale, kernel=linear, max_iter=10000; total time= 8.0min
# [CV] END ..C=1.0, gamma=scale, kernel=linear, max_iter=10000; total time= 8.0min
# [CV] END .......C=1.0, gamma=scale, kernel=rbf, max_iter=100; total time=   5.8s
# [CV] END .......C=1.0, gamma=scale, kernel=rbf, max_iter=100; total time=   5.8s
# [CV] END .......C=1.0, gamma=scale, kernel=rbf, max_iter=100; total time=   5.5s
# [CV] END .......C=1.0, gamma=scale, kernel=rbf, max_iter=100; total time=   5.7s
# [CV] END .......C=1.0, gamma=scale, kernel=rbf, max_iter=100; total time=   5.7s
# [CV] END ..C=1.0, gamma=scale, kernel=linear, max_iter=10000; total time= 7.9min
# [CV] END ..C=1.0, gamma=scale, kernel=linear, max_iter=10000; total time= 8.0min
# [CV] END ......C=1.0, gamma=scale, kernel=rbf, max_iter=1000; total time=  59.6s
# [CV] END ......C=1.0, gamma=scale, kernel=rbf, max_iter=1000; total time= 1.0min
# [CV] END ......C=1.0, gamma=scale, kernel=rbf, max_iter=1000; total time=  59.0s
# [CV] END ......C=1.0, gamma=scale, kernel=rbf, max_iter=1000; total time= 1.0min
# [CV] END ......C=1.0, gamma=scale, kernel=rbf, max_iter=1000; total time= 1.0min
# [CV] END ....C=1.0, gamma=scale, kernel=poly, max_iter=10000; total time=25.3min
# [CV] END ....C=1.0, gamma=scale, kernel=poly, max_iter=10000; total time=25.1min
# [CV] END ....C=1.0, gamma=scale, kernel=poly, max_iter=10000; total time=25.2min
# [CV] END ...C=1.0, gamma=scale, kernel=sigmoid, max_iter=100; total time=   4.6s
# [CV] END ...C=1.0, gamma=scale, kernel=sigmoid, max_iter=100; total time=   4.9s
# [CV] END ...C=1.0, gamma=scale, kernel=sigmoid, max_iter=100; total time=   4.5s
# [CV] END ...C=1.0, gamma=scale, kernel=sigmoid, max_iter=100; total time=   4.9s
# [CV] END ...C=1.0, gamma=scale, kernel=sigmoid, max_iter=100; total time=   4.7s
# [CV] END ..C=1.0, gamma=scale, kernel=sigmoid, max_iter=1000; total time=16.1min
# [CV] END ..C=1.0, gamma=scale, kernel=sigmoid, max_iter=1000; total time=16.3min
# [CV] END ..C=1.0, gamma=scale, kernel=sigmoid, max_iter=1000; total time=  48.0s
# [CV] END ..C=1.0, gamma=scale, kernel=sigmoid, max_iter=1000; total time=  50.3s
# [CV] END ....C=1.0, gamma=scale, kernel=poly, max_iter=10000; total time=55.3min
# [CV] END ..C=1.0, gamma=scale, kernel=sigmoid, max_iter=1000; total time=  52.1s
# [CV] END ....C=1.0, gamma=scale, kernel=poly, max_iter=10000; total time=55.3min
# [CV] END .....C=1.0, gamma=scale, kernel=rbf, max_iter=10000; total time=55.3min
# [CV] END .....C=1.0, gamma=scale, kernel=rbf, max_iter=10000; total time=55.3min
# [CV] END .....C=1.0, gamma=scale, kernel=rbf, max_iter=10000; total time=55.3min
# [CV] END .....C=1.0, gamma=auto, kernel=linear, max_iter=100; total time=   5.8s
# [CV] END .....C=1.0, gamma=auto, kernel=linear, max_iter=100; total time=   5.7s
# [CV] END .....C=1.0, gamma=auto, kernel=linear, max_iter=100; total time=   5.5s
# [CV] END .....C=1.0, gamma=auto, kernel=linear, max_iter=100; total time=   6.0s
# [CV] END .....C=1.0, gamma=auto, kernel=linear, max_iter=100; total time=   5.9s
# [CV] END .....C=1.0, gamma=scale, kernel=rbf, max_iter=10000; total time=39.9min
# [CV] END ....C=1.0, gamma=auto, kernel=linear, max_iter=1000; total time= 1.1min
# [CV] END .....C=1.0, gamma=scale, kernel=rbf, max_iter=10000; total time=40.2min
# [CV] END ....C=1.0, gamma=auto, kernel=linear, max_iter=1000; total time= 1.2min
# [CV] END ....C=1.0, gamma=auto, kernel=linear, max_iter=1000; total time= 1.2min
# [CV] END ....C=1.0, gamma=auto, kernel=linear, max_iter=1000; total time= 1.2min
# [CV] END ....C=1.0, gamma=auto, kernel=linear, max_iter=1000; total time= 1.2min
# [CV] END .C=1.0, gamma=scale, kernel=sigmoid, max_iter=10000; total time= 9.0min
# [CV] END .C=1.0, gamma=scale, kernel=sigmoid, max_iter=10000; total time= 9.1min
# [CV] END .C=1.0, gamma=scale, kernel=sigmoid, max_iter=10000; total time= 9.1min
# [CV] END .......C=1.0, gamma=auto, kernel=poly, max_iter=100; total time=   6.9s
# [CV] END .......C=1.0, gamma=auto, kernel=poly, max_iter=100; total time=   6.9s
# [CV] END .......C=1.0, gamma=auto, kernel=poly, max_iter=100; total time=   6.7s
# [CV] END .......C=1.0, gamma=auto, kernel=poly, max_iter=100; total time=   6.9s
# [CV] END .......C=1.0, gamma=auto, kernel=poly, max_iter=100; total time=   7.0s
# [CV] END ......C=1.0, gamma=auto, kernel=poly, max_iter=1000; total time= 1.1min
# [CV] END .C=1.0, gamma=scale, kernel=sigmoid, max_iter=10000; total time= 9.5min
# [CV] END ......C=1.0, gamma=auto, kernel=poly, max_iter=1000; total time= 1.2min
# [CV] END .C=1.0, gamma=scale, kernel=sigmoid, max_iter=10000; total time= 9.7min
# [CV] END ......C=1.0, gamma=auto, kernel=poly, max_iter=1000; total time= 1.2min
# [CV] END ......C=1.0, gamma=auto, kernel=poly, max_iter=1000; total time= 1.2min
# [CV] END ......C=1.0, gamma=auto, kernel=poly, max_iter=1000; total time=16.7min
# [CV] END ...C=1.0, gamma=auto, kernel=linear, max_iter=10000; total time=24.9min
# [CV] END ...C=1.0, gamma=auto, kernel=linear, max_iter=10000; total time=24.7min
# [CV] END ...C=1.0, gamma=auto, kernel=linear, max_iter=10000; total time=24.7min
# [CV] END ........C=1.0, gamma=auto, kernel=rbf, max_iter=100; total time=   5.4s
# [CV] END ........C=1.0, gamma=auto, kernel=rbf, max_iter=100; total time=   5.2s
# [CV] END ........C=1.0, gamma=auto, kernel=rbf, max_iter=100; total time=   5.3s
# [CV] END ........C=1.0, gamma=auto, kernel=rbf, max_iter=100; total time=   4.9s
# [CV] END ........C=1.0, gamma=auto, kernel=rbf, max_iter=100; total time=   5.2s
# [CV] END .......C=1.0, gamma=auto, kernel=rbf, max_iter=1000; total time=  48.8s
# [CV] END ...C=1.0, gamma=auto, kernel=linear, max_iter=10000; total time=39.4min
# [CV] END .......C=1.0, gamma=auto, kernel=rbf, max_iter=1000; total time=16.2min
# [CV] END ...C=1.0, gamma=auto, kernel=linear, max_iter=10000; total time=39.5min
# [CV] END .......C=1.0, gamma=auto, kernel=rbf, max_iter=1000; total time=  45.3s
# [CV] END .......C=1.0, gamma=auto, kernel=rbf, max_iter=1000; total time=  44.5s
# [CV] END .......C=1.0, gamma=auto, kernel=rbf, max_iter=1000; total time=  44.9s
# [CV] END .....C=1.0, gamma=auto, kernel=poly, max_iter=10000; total time=71.0min
# [CV] END .....C=1.0, gamma=auto, kernel=poly, max_iter=10000; total time=70.9min
# [CV] END .....C=1.0, gamma=auto, kernel=poly, max_iter=10000; total time=55.3min
# [CV] END ....C=1.0, gamma=auto, kernel=sigmoid, max_iter=100; total time=   4.8s
# [CV] END ....C=1.0, gamma=auto, kernel=sigmoid, max_iter=100; total time=   4.6s
# [CV] END ....C=1.0, gamma=auto, kernel=sigmoid, max_iter=100; total time=   4.6s
# [CV] END ....C=1.0, gamma=auto, kernel=sigmoid, max_iter=100; total time=   4.8s
# [CV] END ....C=1.0, gamma=auto, kernel=sigmoid, max_iter=100; total time=   4.5s
# [CV] END ...C=1.0, gamma=auto, kernel=sigmoid, max_iter=1000; total time=16.4min
# [CV] END .....C=1.0, gamma=auto, kernel=poly, max_iter=10000; total time=70.9min
# [CV] END ...C=1.0, gamma=auto, kernel=sigmoid, max_iter=1000; total time=  42.7s
# [CV] END .....C=1.0, gamma=auto, kernel=poly, max_iter=10000; total time=70.9min
# [CV] END ...C=1.0, gamma=auto, kernel=sigmoid, max_iter=1000; total time=  43.2s
# [CV] END ...C=1.0, gamma=auto, kernel=sigmoid, max_iter=1000; total time=13.2min
# [CV] END ...C=1.0, gamma=auto, kernel=sigmoid, max_iter=1000; total time=13.2min
# [CV] END ......C=1.0, gamma=auto, kernel=rbf, max_iter=10000; total time=68.5min
# [CV] END ......C=1.0, gamma=auto, kernel=rbf, max_iter=10000; total time=68.6min
# [CV] END ......C=1.0, gamma=auto, kernel=rbf, max_iter=10000; total time=68.6min
# [CV] END ....C=0.1, gamma=scale, kernel=linear, max_iter=100; total time=   5.0s
# [CV] END ....C=0.1, gamma=scale, kernel=linear, max_iter=100; total time=   5.2s
# [CV] END ....C=0.1, gamma=scale, kernel=linear, max_iter=100; total time=   5.0s
# [CV] END ....C=0.1, gamma=scale, kernel=linear, max_iter=100; total time=   5.2s
# [CV] END ....C=0.1, gamma=scale, kernel=linear, max_iter=100; total time=   5.1s
# [CV] END ...C=0.1, gamma=scale, kernel=linear, max_iter=1000; total time=  52.2s
# [CV] END ...C=0.1, gamma=scale, kernel=linear, max_iter=1000; total time=  54.3s
# [CV] END ...C=0.1, gamma=scale, kernel=linear, max_iter=1000; total time=  54.3s
# [CV] END ......C=1.0, gamma=auto, kernel=rbf, max_iter=10000; total time=37.5min
# [CV] END ......C=1.0, gamma=auto, kernel=rbf, max_iter=10000; total time=37.6min
# [CV] END ...C=0.1, gamma=scale, kernel=linear, max_iter=1000; total time=  54.4s
# [CV] END ...C=0.1, gamma=scale, kernel=linear, max_iter=1000; total time=  53.6s
# [CV] END ..C=1.0, gamma=auto, kernel=sigmoid, max_iter=10000; total time=21.9min
# [CV] END ..C=1.0, gamma=auto, kernel=sigmoid, max_iter=10000; total time= 9.4min
# [CV] END ..C=1.0, gamma=auto, kernel=sigmoid, max_iter=10000; total time= 9.4min
# [CV] END ......C=0.1, gamma=scale, kernel=poly, max_iter=100; total time=   5.3s
# [CV] END ......C=0.1, gamma=scale, kernel=poly, max_iter=100; total time=   5.5s
# [CV] END ......C=0.1, gamma=scale, kernel=poly, max_iter=100; total time=   5.6s
# [CV] END ......C=0.1, gamma=scale, kernel=poly, max_iter=100; total time=   6.3s
# [CV] END ......C=0.1, gamma=scale, kernel=poly, max_iter=100; total time=   6.2s
# [CV] END .....C=0.1, gamma=scale, kernel=poly, max_iter=1000; total time=  55.3s
# [CV] END .....C=0.1, gamma=scale, kernel=poly, max_iter=1000; total time=  55.5s
# [CV] END ..C=1.0, gamma=auto, kernel=sigmoid, max_iter=10000; total time= 9.7min
# [CV] END ..C=1.0, gamma=auto, kernel=sigmoid, max_iter=10000; total time= 9.6min
# [CV] END .....C=0.1, gamma=scale, kernel=poly, max_iter=1000; total time=  54.6s
# [CV] END .....C=0.1, gamma=scale, kernel=poly, max_iter=1000; total time=  54.5s
# [CV] END .....C=0.1, gamma=scale, kernel=poly, max_iter=1000; total time=  52.5s
# [CV] END ..C=0.1, gamma=scale, kernel=linear, max_iter=10000; total time=10.3min
# [CV] END ..C=0.1, gamma=scale, kernel=linear, max_iter=10000; total time=10.3min
# [CV] END ..C=0.1, gamma=scale, kernel=linear, max_iter=10000; total time=10.3min
# [CV] END .......C=0.1, gamma=scale, kernel=rbf, max_iter=100; total time=   5.4s
# [CV] END .......C=0.1, gamma=scale, kernel=rbf, max_iter=100; total time=   5.6s
# [CV] END .......C=0.1, gamma=scale, kernel=rbf, max_iter=100; total time=   5.6s
# [CV] END .......C=0.1, gamma=scale, kernel=rbf, max_iter=100; total time=   5.8s
# [CV] END .......C=0.1, gamma=scale, kernel=rbf, max_iter=100; total time=   6.0s
# [CV] END ......C=0.1, gamma=scale, kernel=rbf, max_iter=1000; total time=  57.6s
# [CV] END ..C=0.1, gamma=scale, kernel=linear, max_iter=10000; total time=10.4min
# [CV] END ......C=0.1, gamma=scale, kernel=rbf, max_iter=1000; total time=  57.5s
# [CV] END ..C=0.1, gamma=scale, kernel=linear, max_iter=10000; total time=10.4min
# [CV] END ......C=0.1, gamma=scale, kernel=rbf, max_iter=1000; total time=  57.8s
# [CV] END ......C=0.1, gamma=scale, kernel=rbf, max_iter=1000; total time=  57.8s
# [CV] END ......C=0.1, gamma=scale, kernel=rbf, max_iter=1000; total time=  56.5s
# [CV] END ....C=0.1, gamma=scale, kernel=poly, max_iter=10000; total time= 9.8min
# [CV] END ....C=0.1, gamma=scale, kernel=poly, max_iter=10000; total time= 9.8min
# [CV] END ....C=0.1, gamma=scale, kernel=poly, max_iter=10000; total time= 9.9min
# [CV] END ...C=0.1, gamma=scale, kernel=sigmoid, max_iter=100; total time=   5.4s
# [CV] END ...C=0.1, gamma=scale, kernel=sigmoid, max_iter=100; total time=   5.4s
# [CV] END ...C=0.1, gamma=scale, kernel=sigmoid, max_iter=100; total time=   5.1s
# [CV] END ...C=0.1, gamma=scale, kernel=sigmoid, max_iter=100; total time=   5.0s
# [CV] END ...C=0.1, gamma=scale, kernel=sigmoid, max_iter=100; total time=   5.0s
# [CV] END ..C=0.1, gamma=scale, kernel=sigmoid, max_iter=1000; total time=  54.4s
# [CV] END ..C=0.1, gamma=scale, kernel=sigmoid, max_iter=1000; total time=  54.3s
# [CV] END ..C=0.1, gamma=scale, kernel=sigmoid, max_iter=1000; total time=  55.4s
# [CV] END ....C=0.1, gamma=scale, kernel=poly, max_iter=10000; total time= 9.8min
# [CV] END ....C=0.1, gamma=scale, kernel=poly, max_iter=10000; total time= 9.9min
# [CV] END ..C=0.1, gamma=scale, kernel=sigmoid, max_iter=1000; total time=  54.3s
# [CV] END ..C=0.1, gamma=scale, kernel=sigmoid, max_iter=1000; total time=  56.1s
# [CV] END .....C=0.1, gamma=scale, kernel=rbf, max_iter=10000; total time=10.9min
# [CV] END .....C=0.1, gamma=scale, kernel=rbf, max_iter=10000; total time=10.9min
# [CV] END .....C=0.1, gamma=scale, kernel=rbf, max_iter=10000; total time=10.9min
# [CV] END .....C=0.1, gamma=auto, kernel=linear, max_iter=100; total time=   5.0s
# [CV] END .....C=0.1, gamma=auto, kernel=linear, max_iter=100; total time=   5.2s
# [CV] END .....C=0.1, gamma=auto, kernel=linear, max_iter=100; total time=   5.0s
# [CV] END .....C=0.1, gamma=auto, kernel=linear, max_iter=100; total time=   5.4s
# [CV] END .....C=0.1, gamma=auto, kernel=linear, max_iter=100; total time=   5.2s
# [CV] END ....C=0.1, gamma=auto, kernel=linear, max_iter=1000; total time=  53.6s
# [CV] END .....C=0.1, gamma=scale, kernel=rbf, max_iter=10000; total time=10.8min
# [CV] END .....C=0.1, gamma=scale, kernel=rbf, max_iter=10000; total time=10.8min
# [CV] END ....C=0.1, gamma=auto, kernel=linear, max_iter=1000; total time=  55.0s
# [CV] END ....C=0.1, gamma=auto, kernel=linear, max_iter=1000; total time=  56.3s
# [CV] END ....C=0.1, gamma=auto, kernel=linear, max_iter=1000; total time=  56.3s
# [CV] END ....C=0.1, gamma=auto, kernel=linear, max_iter=1000; total time=  55.6s
# [CV] END .C=0.1, gamma=scale, kernel=sigmoid, max_iter=10000; total time=10.6min
# [CV] END .C=0.1, gamma=scale, kernel=sigmoid, max_iter=10000; total time=10.6min
# [CV] END .C=0.1, gamma=scale, kernel=sigmoid, max_iter=10000; total time=10.6min
# [CV] END .......C=0.1, gamma=auto, kernel=poly, max_iter=100; total time=   5.6s
# [CV] END .......C=0.1, gamma=auto, kernel=poly, max_iter=100; total time=   5.7s
# [CV] END .......C=0.1, gamma=auto, kernel=poly, max_iter=100; total time=   5.6s
# [CV] END .......C=0.1, gamma=auto, kernel=poly, max_iter=100; total time=   5.6s
# [CV] END .......C=0.1, gamma=auto, kernel=poly, max_iter=100; total time=   5.6s
# [CV] END ......C=0.1, gamma=auto, kernel=poly, max_iter=1000; total time=  54.4s
# [CV] END ......C=0.1, gamma=auto, kernel=poly, max_iter=1000; total time=  56.1s
# [CV] END .C=0.1, gamma=scale, kernel=sigmoid, max_iter=10000; total time=10.5min
# [CV] END ......C=0.1, gamma=auto, kernel=poly, max_iter=1000; total time=  57.0s
# [CV] END .C=0.1, gamma=scale, kernel=sigmoid, max_iter=10000; total time=10.5min
# [CV] END ......C=0.1, gamma=auto, kernel=poly, max_iter=1000; total time=  57.7s
# [CV] END ......C=0.1, gamma=auto, kernel=poly, max_iter=1000; total time=  57.2s
# [CV] END ...C=0.1, gamma=auto, kernel=linear, max_iter=10000; total time=10.3min
# [CV] END ...C=0.1, gamma=auto, kernel=linear, max_iter=10000; total time=10.3min
# [CV] END ...C=0.1, gamma=auto, kernel=linear, max_iter=10000; total time=10.3min
# [CV] END ........C=0.1, gamma=auto, kernel=rbf, max_iter=100; total time=   5.8s
# [CV] END ........C=0.1, gamma=auto, kernel=rbf, max_iter=100; total time=   5.7s
# [CV] END ........C=0.1, gamma=auto, kernel=rbf, max_iter=100; total time=   5.8s
# [CV] END ........C=0.1, gamma=auto, kernel=rbf, max_iter=100; total time=   5.5s
# [CV] END ........C=0.1, gamma=auto, kernel=rbf, max_iter=100; total time=   5.4s
# [CV] END .......C=0.1, gamma=auto, kernel=rbf, max_iter=1000; total time=  51.0s
# [CV] END .......C=0.1, gamma=auto, kernel=rbf, max_iter=1000; total time=  50.1s
# [CV] END ...C=0.1, gamma=auto, kernel=linear, max_iter=10000; total time=10.2min
# [CV] END ...C=0.1, gamma=auto, kernel=linear, max_iter=10000; total time=10.2min
# [CV] END .......C=0.1, gamma=auto, kernel=rbf, max_iter=1000; total time=  50.8s
# [CV] END .......C=0.1, gamma=auto, kernel=rbf, max_iter=1000; total time=  52.2s
# [CV] END .......C=0.1, gamma=auto, kernel=rbf, max_iter=1000; total time=  52.5s
# [CV] END .....C=0.1, gamma=auto, kernel=poly, max_iter=10000; total time= 9.4min
# [CV] END .....C=0.1, gamma=auto, kernel=poly, max_iter=10000; total time= 9.5min
# [CV] END .....C=0.1, gamma=auto, kernel=poly, max_iter=10000; total time= 9.5min
# [CV] END ....C=0.1, gamma=auto, kernel=sigmoid, max_iter=100; total time=   6.2s
# [CV] END ....C=0.1, gamma=auto, kernel=sigmoid, max_iter=100; total time=   5.7s
# [CV] END ....C=0.1, gamma=auto, kernel=sigmoid, max_iter=100; total time=   6.0s
# [CV] END ....C=0.1, gamma=auto, kernel=sigmoid, max_iter=100; total time=   6.2s
# [CV] END ....C=0.1, gamma=auto, kernel=sigmoid, max_iter=100; total time=   5.4s
# [CV] END ...C=0.1, gamma=auto, kernel=sigmoid, max_iter=1000; total time=  50.1s
# [CV] END .....C=0.1, gamma=auto, kernel=poly, max_iter=10000; total time= 9.6min
# [CV] END ...C=0.1, gamma=auto, kernel=sigmoid, max_iter=1000; total time=  52.6s
# [CV] END .....C=0.1, gamma=auto, kernel=poly, max_iter=10000; total time= 9.7min
# [CV] END ...C=0.1, gamma=auto, kernel=sigmoid, max_iter=1000; total time=  52.2s
# [CV] END ...C=0.1, gamma=auto, kernel=sigmoid, max_iter=1000; total time=  52.4s
# [CV] END ...C=0.1, gamma=auto, kernel=sigmoid, max_iter=1000; total time=  52.1s
# [CV] END ......C=0.1, gamma=auto, kernel=rbf, max_iter=10000; total time=10.5min
# [CV] END ......C=0.1, gamma=auto, kernel=rbf, max_iter=10000; total time=10.5min
# [CV] END ......C=0.1, gamma=auto, kernel=rbf, max_iter=10000; total time=10.5min
# [CV] END ...C=0.01, gamma=scale, kernel=linear, max_iter=100; total time=   5.7s
# [CV] END ...C=0.01, gamma=scale, kernel=linear, max_iter=100; total time=   5.6s
# [CV] END ...C=0.01, gamma=scale, kernel=linear, max_iter=100; total time=   6.0s
# [CV] END ...C=0.01, gamma=scale, kernel=linear, max_iter=100; total time=   5.3s
# [CV] END ...C=0.01, gamma=scale, kernel=linear, max_iter=100; total time=   5.1s
# [CV] END ..C=0.01, gamma=scale, kernel=linear, max_iter=1000; total time=  54.4s
# [CV] END ..C=0.01, gamma=scale, kernel=linear, max_iter=1000; total time=  53.2s
# [CV] END ......C=0.1, gamma=auto, kernel=rbf, max_iter=10000; total time=10.6min
# [CV] END ..C=0.01, gamma=scale, kernel=linear, max_iter=1000; total time=  52.5s
# [CV] END ......C=0.1, gamma=auto, kernel=rbf, max_iter=10000; total time=10.6min
# [CV] END ..C=0.01, gamma=scale, kernel=linear, max_iter=1000; total time=  52.3s
# [CV] END ..C=0.01, gamma=scale, kernel=linear, max_iter=1000; total time=  53.9s
# [CV] END ..C=0.1, gamma=auto, kernel=sigmoid, max_iter=10000; total time=10.2min
# [CV] END ..C=0.1, gamma=auto, kernel=sigmoid, max_iter=10000; total time=10.2min
# [CV] END ..C=0.1, gamma=auto, kernel=sigmoid, max_iter=10000; total time=10.2min
# [CV] END .....C=0.01, gamma=scale, kernel=poly, max_iter=100; total time=   5.8s
# [CV] END .....C=0.01, gamma=scale, kernel=poly, max_iter=100; total time=   5.8s
# [CV] END .....C=0.01, gamma=scale, kernel=poly, max_iter=100; total time=   5.6s
# [CV] END .....C=0.01, gamma=scale, kernel=poly, max_iter=100; total time=   5.6s
# [CV] END .....C=0.01, gamma=scale, kernel=poly, max_iter=100; total time=   5.7s
# [CV] END ....C=0.01, gamma=scale, kernel=poly, max_iter=1000; total time=  55.2s
# [CV] END ....C=0.01, gamma=scale, kernel=poly, max_iter=1000; total time=  53.9s
# [CV] END ..C=0.1, gamma=auto, kernel=sigmoid, max_iter=10000; total time=10.1min
# [CV] END ....C=0.01, gamma=scale, kernel=poly, max_iter=1000; total time=  55.0s
# [CV] END ..C=0.1, gamma=auto, kernel=sigmoid, max_iter=10000; total time=10.1min
# [CV] END ....C=0.01, gamma=scale, kernel=poly, max_iter=1000; total time=  54.9s
# [CV] END ....C=0.01, gamma=scale, kernel=poly, max_iter=1000; total time=  55.2s
# [CV] END .C=0.01, gamma=scale, kernel=linear, max_iter=10000; total time=10.7min
# [CV] END .C=0.01, gamma=scale, kernel=linear, max_iter=10000; total time=10.8min
# [CV] END .C=0.01, gamma=scale, kernel=linear, max_iter=10000; total time=10.7min
# [CV] END ......C=0.01, gamma=scale, kernel=rbf, max_iter=100; total time=   6.8s
# [CV] END ......C=0.01, gamma=scale, kernel=rbf, max_iter=100; total time=   6.7s
# [CV] END ......C=0.01, gamma=scale, kernel=rbf, max_iter=100; total time=   6.5s
# [CV] END ......C=0.01, gamma=scale, kernel=rbf, max_iter=100; total time=   6.3s
# [CV] END ......C=0.01, gamma=scale, kernel=rbf, max_iter=100; total time=   6.2s
# [CV] END .....C=0.01, gamma=scale, kernel=rbf, max_iter=1000; total time= 1.0min
# [CV] END .C=0.01, gamma=scale, kernel=linear, max_iter=10000; total time=10.9min
# [CV] END .C=0.01, gamma=scale, kernel=linear, max_iter=10000; total time=11.0min
# [CV] END .....C=0.01, gamma=scale, kernel=rbf, max_iter=1000; total time= 1.1min
# [CV] END .....C=0.01, gamma=scale, kernel=rbf, max_iter=1000; total time= 1.1min
# [CV] END .....C=0.01, gamma=scale, kernel=rbf, max_iter=1000; total time= 1.1min
# [CV] END .....C=0.01, gamma=scale, kernel=rbf, max_iter=1000; total time= 1.1min
# [CV] END ...C=0.01, gamma=scale, kernel=poly, max_iter=10000; total time=10.7min
# [CV] END ...C=0.01, gamma=scale, kernel=poly, max_iter=10000; total time=10.8min
# [CV] END ...C=0.01, gamma=scale, kernel=poly, max_iter=10000; total time=10.8min
# [CV] END ..C=0.01, gamma=scale, kernel=sigmoid, max_iter=100; total time=   6.0s
# [CV] END ..C=0.01, gamma=scale, kernel=sigmoid, max_iter=100; total time=   6.5s
# [CV] END ..C=0.01, gamma=scale, kernel=sigmoid, max_iter=100; total time=   6.9s
# [CV] END ..C=0.01, gamma=scale, kernel=sigmoid, max_iter=100; total time=   6.6s
# [CV] END ..C=0.01, gamma=scale, kernel=sigmoid, max_iter=100; total time=   6.2s
# [CV] END .C=0.01, gamma=scale, kernel=sigmoid, max_iter=1000; total time= 1.0min
# [CV] END .C=0.01, gamma=scale, kernel=sigmoid, max_iter=1000; total time= 1.1min
# [CV] END .C=0.01, gamma=scale, kernel=sigmoid, max_iter=1000; total time= 1.0min
# [CV] END ...C=0.01, gamma=scale, kernel=poly, max_iter=10000; total time=11.2min
# [CV] END ...C=0.01, gamma=scale, kernel=poly, max_iter=10000; total time=11.2min
# [CV] END .C=0.01, gamma=scale, kernel=sigmoid, max_iter=1000; total time=  60.0s
# [CV] END .C=0.01, gamma=scale, kernel=sigmoid, max_iter=1000; total time= 1.0min
# [CV] END ....C=0.01, gamma=scale, kernel=rbf, max_iter=10000; total time=12.7min
# [CV] END ....C=0.01, gamma=scale, kernel=rbf, max_iter=10000; total time=12.8min
# [CV] END ....C=0.01, gamma=scale, kernel=rbf, max_iter=10000; total time=12.7min
# [CV] END ....C=0.01, gamma=auto, kernel=linear, max_iter=100; total time=   6.9s
# [CV] END ....C=0.01, gamma=auto, kernel=linear, max_iter=100; total time=   6.5s
# [CV] END ....C=0.01, gamma=auto, kernel=linear, max_iter=100; total time=   6.6s
# [CV] END ....C=0.01, gamma=auto, kernel=linear, max_iter=100; total time=   6.4s
# [CV] END ....C=0.01, gamma=auto, kernel=linear, max_iter=100; total time=   6.0s
# [CV] END ...C=0.01, gamma=auto, kernel=linear, max_iter=1000; total time= 1.1min
# [CV] END ....C=0.01, gamma=scale, kernel=rbf, max_iter=10000; total time=12.9min
# [CV] END ...C=0.01, gamma=auto, kernel=linear, max_iter=1000; total time= 1.1min
# [CV] END ....C=0.01, gamma=scale, kernel=rbf, max_iter=10000; total time=13.0min
# [CV] END ...C=0.01, gamma=auto, kernel=linear, max_iter=1000; total time= 1.1min
# [CV] END ...C=0.01, gamma=auto, kernel=linear, max_iter=1000; total time= 1.0min
# [CV] END ...C=0.01, gamma=auto, kernel=linear, max_iter=1000; total time= 1.1min
# [CV] END C=0.01, gamma=scale, kernel=sigmoid, max_iter=10000; total time=12.7min
# [CV] END C=0.01, gamma=scale, kernel=sigmoid, max_iter=10000; total time=12.6min
# [CV] END C=0.01, gamma=scale, kernel=sigmoid, max_iter=10000; total time=12.7min
# [CV] END ......C=0.01, gamma=auto, kernel=poly, max_iter=100; total time=   6.8s
# [CV] END ......C=0.01, gamma=auto, kernel=poly, max_iter=100; total time=   7.2s
# [CV] END ......C=0.01, gamma=auto, kernel=poly, max_iter=100; total time=   6.9s
# [CV] END ......C=0.01, gamma=auto, kernel=poly, max_iter=100; total time=   6.8s
# [CV] END ......C=0.01, gamma=auto, kernel=poly, max_iter=100; total time=   6.8s
# [CV] END .....C=0.01, gamma=auto, kernel=poly, max_iter=1000; total time= 1.1min
# [CV] END .....C=0.01, gamma=auto, kernel=poly, max_iter=1000; total time= 1.1min
# [CV] END .....C=0.01, gamma=auto, kernel=poly, max_iter=1000; total time= 1.1min
# [CV] END C=0.01, gamma=scale, kernel=sigmoid, max_iter=10000; total time=12.5min
# [CV] END C=0.01, gamma=scale, kernel=sigmoid, max_iter=10000; total time=12.5min
# [CV] END .....C=0.01, gamma=auto, kernel=poly, max_iter=1000; total time= 1.1min
# [CV] END .....C=0.01, gamma=auto, kernel=poly, max_iter=1000; total time= 1.1min
# [CV] END ..C=0.01, gamma=auto, kernel=linear, max_iter=10000; total time=12.0min
# [CV] END ..C=0.01, gamma=auto, kernel=linear, max_iter=10000; total time=12.0min
# [CV] END ..C=0.01, gamma=auto, kernel=linear, max_iter=10000; total time=12.0min
# [CV] END .......C=0.01, gamma=auto, kernel=rbf, max_iter=100; total time=   6.8s
# [CV] END .......C=0.01, gamma=auto, kernel=rbf, max_iter=100; total time=   6.9s
# [CV] END .......C=0.01, gamma=auto, kernel=rbf, max_iter=100; total time=   6.9s
# [CV] END .......C=0.01, gamma=auto, kernel=rbf, max_iter=100; total time=   6.7s
# [CV] END .......C=0.01, gamma=auto, kernel=rbf, max_iter=100; total time=   6.6s
# [CV] END ......C=0.01, gamma=auto, kernel=rbf, max_iter=1000; total time= 1.0min
# [CV] END ......C=0.01, gamma=auto, kernel=rbf, max_iter=1000; total time= 1.0min
# [CV] END ..C=0.01, gamma=auto, kernel=linear, max_iter=10000; total time=11.9min
# [CV] END ..C=0.01, gamma=auto, kernel=linear, max_iter=10000; total time=12.0min
# [CV] END ......C=0.01, gamma=auto, kernel=rbf, max_iter=1000; total time= 1.1min
# [CV] END ......C=0.01, gamma=auto, kernel=rbf, max_iter=1000; total time= 1.1min
# [CV] END ......C=0.01, gamma=auto, kernel=rbf, max_iter=1000; total time= 1.1min
# [CV] END ....C=0.01, gamma=auto, kernel=poly, max_iter=10000; total time=11.7min
# [CV] END ....C=0.01, gamma=auto, kernel=poly, max_iter=10000; total time=11.7min
# [CV] END ....C=0.01, gamma=auto, kernel=poly, max_iter=10000; total time=11.8min
# [CV] END ...C=0.01, gamma=auto, kernel=sigmoid, max_iter=100; total time=   7.3s
# [CV] END ...C=0.01, gamma=auto, kernel=sigmoid, max_iter=100; total time=   6.7s
# [CV] END ...C=0.01, gamma=auto, kernel=sigmoid, max_iter=100; total time=   7.0s
# [CV] END ...C=0.01, gamma=auto, kernel=sigmoid, max_iter=100; total time=   6.5s
# [CV] END ...C=0.01, gamma=auto, kernel=sigmoid, max_iter=100; total time=   6.6s
# [CV] END ..C=0.01, gamma=auto, kernel=sigmoid, max_iter=1000; total time= 1.1min
# [CV] END ..C=0.01, gamma=auto, kernel=sigmoid, max_iter=1000; total time= 1.0min
# [CV] END ....C=0.01, gamma=auto, kernel=poly, max_iter=10000; total time=12.0min
# [CV] END ....C=0.01, gamma=auto, kernel=poly, max_iter=10000; total time=12.1min
# [CV] END ..C=0.01, gamma=auto, kernel=sigmoid, max_iter=1000; total time= 1.1min
# [CV] END ..C=0.01, gamma=auto, kernel=sigmoid, max_iter=1000; total time= 1.1min
# [CV] END ..C=0.01, gamma=auto, kernel=sigmoid, max_iter=1000; total time= 1.1min
# [CV] END .....C=0.01, gamma=auto, kernel=rbf, max_iter=10000; total time=13.0min
# [CV] END .....C=0.01, gamma=auto, kernel=rbf, max_iter=10000; total time=13.0min
# [CV] END .....C=0.01, gamma=auto, kernel=rbf, max_iter=10000; total time=13.0min
# [CV] END .....C=0.01, gamma=auto, kernel=rbf, max_iter=10000; total time=12.6min
# [CV] END .....C=0.01, gamma=auto, kernel=rbf, max_iter=10000; total time=12.6min
# [CV] END .C=0.01, gamma=auto, kernel=sigmoid, max_iter=10000; total time=11.4min
# [CV] END .C=0.01, gamma=auto, kernel=sigmoid, max_iter=10000; total time=11.3min
# [CV] END .C=0.01, gamma=auto, kernel=sigmoid, max_iter=10000; total time=11.2min
# [CV] END .C=0.01, gamma=auto, kernel=sigmoid, max_iter=10000; total time= 9.4min
# [CV] END .C=0.01, gamma=auto, kernel=sigmoid, max_iter=10000; total time= 9.1min

# %%
# see which hyperparameters were selected as best
print(best_params)

# Use best hyperparameters to create the best SVM classifier
best_svc = SVC(C=best_params['C'],
               gamma=best_params['gamma'],
               kernel=best_params['kernel'],
               max_iter=best_params['max_iter'],
               probability=True,
               verbose=True)

# Fit the best SVC to the training data
best_svc.fit(X_train_tfidf, y_train)

# Predict sentiment of the testing data with model
y_pred = best_svc.predict(X_test_tfidf)

# Calculate the raw accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# create and print classification report of model
# this allows us to evaluate the performance of both classes
# this is important due to class imbalance
print(classification_report(y_test, y_pred))

# predict probabilities for the test data using the SVC classifier
#TODO: Determine whether this is apposite or another method is needed
y_pred_proba = best_svc.predict_proba(X_test_tfidf)[:, 1]

# calculate the AUC-ROC metric
# this is valuable due to class imbalance
auc_roc = roc_auc_score(y_test, y_pred_proba)
print(f"AUC-ROC: {auc_roc}")

#RUNTIME: 51m 49s
# Out:
# {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': 10000}
# [LibSVM].........WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 10000
# obj = -9030.704589, rho = -0.546964
# nSV = 17794, nBSV = 10625
# Total nSV = 17794
# .........WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 10000
# obj = -9033.440791, rho = -0.567543
# nSV = 17744, nBSV = 10598
# Total nSV = 17744
# .........WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 10000
# obj = -9080.360890, rho = -0.553087
# nSV = 17780, nBSV = 10666
# Total nSV = 17780
# .........WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 10000
# obj = -9079.404991, rho = -0.325732
# nSV = 17759, nBSV = 10674
# Total nSV = 17759
# .........WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 10000
# obj = -9019.183354, rho = -0.544717
# nSV = 17735, nBSV = 10550
# Total nSV = 17735
# .........WARN: libsvm Solver reached max_iter
# optimization finished, #iter = 10000
# obj = -10710.578558, rho = 0.505837
# nSV = 19022, nBSV = 13951
# Total nSV = 19022
# Accuracy: 0.92375
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.83      4669
#            1       0.94      0.96      0.95     15331
#
#     accuracy                           0.92     20000
#    macro avg       0.90      0.88      0.89     20000
# weighted avg       0.92      0.92      0.92     20000
#
# AUC-ROC: 0.9680602266214099

# %% [markdown]
# ### Full model readout:

# %%
#Hyperparameters:
#{'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': 10000}

# Accuracy: 0.92375
#               precision    recall  f1-score   support

#            0       0.86      0.81      0.83      4669
#            1       0.94      0.96      0.95     15331

#     accuracy                           0.92     20000
#    macro avg       0.90      0.88      0.89     20000
# weighted avg       0.92      0.92      0.92     20000

# AUC-ROC: 0.9680602266214099

# %% [markdown]
# ### Bonus: LinearSVC

# %%
lin_svc = LinearSVC(verbose=True)
lin_svc.fit(X_train_tfidf, y_train)

ylin_pred = lin_svc.predict(X_test_tfidf)

accuracy = accuracy_score(y_test, ylin_pred)
print(f"Accuracy: {accuracy}")

print(classification_report(y_test, ylin_pred))

# AttributeError: 'LinearSVC' object has no attribute 'predict_proba'
#ylin_pred_proba = lin_svc.predict_proba(X_test_tfidf)[:, 1]
# TODO: Determine whether an analogue of this pred_proba is needed for valid results

# calculate the AUC-ROC metric. this is valuable due to class imbalance
#auc_roc_lin = roc_auc_score(y_test, ylin_pred_proba)

auc_roc_lin = roc_auc_score(y_test, ylin_pred) #without proba
print(f"AUC-ROC: {auc_roc_lin}")

#RUNTIME: 0.6s?!
# Out:
# [LibLinear]....*
# optimization finished, #iter = 49
# Objective value = -12008.032805
# nSV = 27862
# Accuracy: 0.9208
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83      4669
#            1       0.94      0.96      0.95     15331
#
#     accuracy                           0.92     20000
#    macro avg       0.89      0.88      0.89     20000
# weighted avg       0.92      0.92      0.92     20000
#
# AUC-ROC: 0.8806415953945184
