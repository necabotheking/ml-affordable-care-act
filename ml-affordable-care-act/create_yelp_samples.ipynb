# %% [markdown]
# ## Yelp dataset readin code
# For: CAPP 30254 - Machine Learning for Public Policy<br>
# Spring 2023<br>
# By: Matt Jackson<br>
#
# The original Yelp dataset is over 5GB in size, is 6.9+ million rows long, and contains several redundant columns that we don't need. That is both unwieldy and too big to play nicely with GitHub or pandas.
#
# This code takes the original Yelp dataset into pandas, removes the unnecessary columns, and creates two kinds of sample file for exploratory analysis and model training:
#
# * `yelp_true_sample`: A truly random sample of 100,000 of the Yelp reviews
# * `yelp_oversample`: An "oversample" in which there are 20,000 reviews of each star rating (1 through 5) (for a total of 100,000 reviews)
#
# It does _not_ do any text pre-processing.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# _There is no need to run this once the sample datasets are available. Preserving the code for posterity and reproducibility, though._

# %%
#Read in the original Yelp JSON as "chunks", which are smaller and can be concatenated
#to recreate whole dataset without crashing pandas 
#https://stackoverflow.com/questions/46790390/how-to-read-a-large-json-in-pandas

#"yelp_dataset/yelp_academic_dataset_review.json" is the original 5GB file
#This takes about 5 minutes.
chunks = pd.read_json("yelp_dataset/yelp_academic_dataset_review.json", lines=True, chunksize = 10000)
#there are 700 chunks
reviews = pd.DataFrame()
for i, chunk in enumerate(chunks):
  print(f"Now concatenating chunk {i}...")
  reviews = pd.concat([reviews, chunk])
print("Full dataset load complete")
# Out:
# Now concatenating chunk 0...
# Now concatenating chunk 1...
# Now concatenating chunk 2...
# Now concatenating chunk 3...
# Now concatenating chunk 4...
# Now concatenating chunk 5...
# Now concatenating chunk 6...
# Now concatenating chunk 7...
# Now concatenating chunk 8...
# Now concatenating chunk 9...
# Now concatenating chunk 10...
# Now concatenating chunk 11...
# Now concatenating chunk 12...
# Now concatenating chunk 13...
# Now concatenating chunk 14...
# Now concatenating chunk 15...
# Now concatenating chunk 16...
# Now concatenating chunk 17...
# Now concatenating chunk 18...
# Now concatenating chunk 19...
# Now concatenating chunk 20...
# Now concatenating chunk 21...
# Now concatenating chunk 22...
# Now concatenating chunk 23...
# Now concatenating chunk 24...
# Now concatenating chunk 25...
# Now concatenating chunk 26...
# Now concatenating chunk 27...
# Now concatenating chunk 28...
# Now concatenating chunk 29...
# Now concatenating chunk 30...
# Now concatenating chunk 31...
# Now concatenating chunk 32...
# Now concatenating chunk 33...
# Now concatenating chunk 34...
# Now concatenating chunk 35...
# Now concatenating chunk 36...
# Now concatenating chunk 37...
# Now concatenating chunk 38...
# Now concatenating chunk 39...
# Now concatenating chunk 40...
# Now concatenating chunk 41...
# Now concatenating chunk 42...
# Now concatenating chunk 43...
# Now concatenating chunk 44...
# Now concatenating chunk 45...
# Now concatenating chunk 46...
# Now concatenating chunk 47...
# Now concatenating chunk 48...
# Now concatenating chunk 49...
# Now concatenating chunk 50...
# Now concatenating chunk 51...
# Now concatenating chunk 52...
# Now concatenating chunk 53...
# Now concatenating chunk 54...
# Now concatenating chunk 55...
# Now concatenating chunk 56...
# Now concatenating chunk 57...
# Now concatenating chunk 265...
# Now concatenating chunk 266...
# Now concatenating chunk 267...
# Now concatenating chunk 268...
# Now concatenating chunk 269...
# Now concatenating chunk 270...
# Now concatenating chunk 271...
# Now concatenating chunk 272...
# Now concatenating chunk 273...
# Now concatenating chunk 274...
# Now concatenating chunk 275...
# Now concatenating chunk 276...
# Now concatenating chunk 277...
# Now concatenating chunk 278...
# Now concatenating chunk 279...
# Now concatenating chunk 280...
# Now concatenating chunk 281...
# Now concatenating chunk 282...
# Now concatenating chunk 283...
# Now concatenating chunk 284...
# Now concatenating chunk 285...
# Now concatenating chunk 286...
# Now concatenating chunk 287...
# Now concatenating chunk 288...
# Now concatenating chunk 289...
# Now concatenating chunk 290...
# Now concatenating chunk 291...
# Now concatenating chunk 292...
# Now concatenating chunk 293...
# Now concatenating chunk 294...
# Now concatenating chunk 295...
# Now concatenating chunk 296...
# Now concatenating chunk 297...
# Now concatenating chunk 298...
# Now concatenating chunk 299...
# Now concatenating chunk 300...
# Now concatenating chunk 301...
# Now concatenating chunk 302...
# Now concatenating chunk 303...
# Now concatenating chunk 304...
# Now concatenating chunk 305...
# Now concatenating chunk 306...
# Now concatenating chunk 307...
# Now concatenating chunk 308...
# Now concatenating chunk 309...
# Now concatenating chunk 310...
# Now concatenating chunk 311...
# Now concatenating chunk 312...
# Now concatenating chunk 313...
# Now concatenating chunk 314...
# Now concatenating chunk 315...
# Now concatenating chunk 316...
# Now concatenating chunk 317...
# Now concatenating chunk 318...
# Now concatenating chunk 319...
# Now concatenating chunk 320...
# Now concatenating chunk 321...
# Now concatenating chunk 322...
# Now concatenating chunk 323...
# Now concatenating chunk 324...
# Now concatenating chunk 325...
# Now concatenating chunk 326...
# Now concatenating chunk 327...
# Now concatenating chunk 328...
# Now concatenating chunk 329...
# Now concatenating chunk 330...
# Now concatenating chunk 331...
# Now concatenating chunk 332...
# Now concatenating chunk 333...
# Now concatenating chunk 334...
# Now concatenating chunk 335...
# Now concatenating chunk 336...
# Now concatenating chunk 337...
# Now concatenating chunk 338...
# Now concatenating chunk 339...
# Now concatenating chunk 340...
# Now concatenating chunk 341...
# Now concatenating chunk 342...
# Now concatenating chunk 343...
# Now concatenating chunk 344...
# Now concatenating chunk 345...
# Now concatenating chunk 346...
# Now concatenating chunk 347...
# Now concatenating chunk 348...
# Now concatenating chunk 349...
# Now concatenating chunk 350...
# Now concatenating chunk 351...
# Now concatenating chunk 352...
# Now concatenating chunk 353...
# Now concatenating chunk 354...
# Now concatenating chunk 355...
# Now concatenating chunk 356...
# Now concatenating chunk 357...
# Now concatenating chunk 358...
# Now concatenating chunk 359...
# Now concatenating chunk 360...
# Now concatenating chunk 361...
# Now concatenating chunk 362...
# Now concatenating chunk 363...
# Now concatenating chunk 364...
# Now concatenating chunk 365...
# Now concatenating chunk 366...
# Now concatenating chunk 367...
# Now concatenating chunk 368...
# Now concatenating chunk 369...
# Now concatenating chunk 370...
# Now concatenating chunk 371...
# Now concatenating chunk 372...
# Now concatenating chunk 373...
# Now concatenating chunk 374...
# Now concatenating chunk 375...
# Now concatenating chunk 376...
# Now concatenating chunk 377...
# Now concatenating chunk 378...
# Now concatenating chunk 379...
# Now concatenating chunk 380...
# Now concatenating chunk 381...
# Now concatenating chunk 382...
# Now concatenating chunk 383...
# Now concatenating chunk 384...
# Now concatenating chunk 385...
# Now concatenating chunk 386...
# Now concatenating chunk 387...
# Now concatenating chunk 388...
# Now concatenating chunk 389...
# Now concatenating chunk 390...
# Now concatenating chunk 391...
# Now concatenating chunk 392...
# Now concatenating chunk 393...
# Now concatenating chunk 394...
# Now concatenating chunk 395...
# Now concatenating chunk 396...
# Now concatenating chunk 397...
# Now concatenating chunk 398...
# Now concatenating chunk 399...
# Now concatenating chunk 400...
# Now concatenating chunk 401...
# Now concatenating chunk 402...
# Now concatenating chunk 403...
# Now concatenating chunk 404...
# Now concatenating chunk 405...
# Now concatenating chunk 406...
# Now concatenating chunk 407...
# Now concatenating chunk 408...
# Now concatenating chunk 409...
# Now concatenating chunk 410...
# Now concatenating chunk 411...
# Now concatenating chunk 412...
# Now concatenating chunk 413...
# Now concatenating chunk 414...
# Now concatenating chunk 415...
# Now concatenating chunk 416...
# Now concatenating chunk 417...
# Now concatenating chunk 418...
# Now concatenating chunk 419...
# Now concatenating chunk 420...
# Now concatenating chunk 421...
# Now concatenating chunk 422...
# Now concatenating chunk 423...
# Now concatenating chunk 424...
# Now concatenating chunk 425...
# Now concatenating chunk 426...
# Now concatenating chunk 427...
# Now concatenating chunk 428...
# Now concatenating chunk 429...
# Now concatenating chunk 430...
# Now concatenating chunk 431...
# Now concatenating chunk 432...
# Now concatenating chunk 433...
# Now concatenating chunk 434...
# Now concatenating chunk 435...
# Now concatenating chunk 436...
# Now concatenating chunk 437...
# Now concatenating chunk 438...
# Now concatenating chunk 439...
# Now concatenating chunk 440...
# Now concatenating chunk 441...
# Now concatenating chunk 442...
# Now concatenating chunk 443...
# Now concatenating chunk 444...
# Now concatenating chunk 445...
# Now concatenating chunk 446...
# Now concatenating chunk 447...
# Now concatenating chunk 448...
# Now concatenating chunk 449...
# Now concatenating chunk 450...
# Now concatenating chunk 451...
# Now concatenating chunk 452...
# Now concatenating chunk 453...
# Now concatenating chunk 454...
# Now concatenating chunk 455...
# Now concatenating chunk 456...
# Now concatenating chunk 457...
# Now concatenating chunk 458...
# Now concatenating chunk 459...
# Now concatenating chunk 460...
# Now concatenating chunk 461...
# Now concatenating chunk 462...
# Now concatenating chunk 463...
# Now concatenating chunk 464...
# Now concatenating chunk 465...
# Now concatenating chunk 466...
# Now concatenating chunk 467...
# Now concatenating chunk 468...
# Now concatenating chunk 469...
# Now concatenating chunk 470...
# Now concatenating chunk 471...
# Now concatenating chunk 472...
# Now concatenating chunk 473...
# Now concatenating chunk 474...
# Now concatenating chunk 475...
# Now concatenating chunk 476...
# Now concatenating chunk 477...
# Now concatenating chunk 478...
# Now concatenating chunk 479...
# Now concatenating chunk 480...
# Now concatenating chunk 481...
# Now concatenating chunk 482...
# Now concatenating chunk 483...
# Now concatenating chunk 484...
# Now concatenating chunk 485...
# Now concatenating chunk 486...
# Now concatenating chunk 487...
# Now concatenating chunk 488...
# Now concatenating chunk 489...
# Now concatenating chunk 490...
# Now concatenating chunk 491...
# Now concatenating chunk 492...
# Now concatenating chunk 493...
# Now concatenating chunk 494...
# Now concatenating chunk 495...
# Now concatenating chunk 496...
# Now concatenating chunk 497...
# Now concatenating chunk 498...
# Now concatenating chunk 499...
# Now concatenating chunk 500...
# Now concatenating chunk 501...
# Now concatenating chunk 502...
# Now concatenating chunk 503...
# Now concatenating chunk 504...
# Now concatenating chunk 505...
# Now concatenating chunk 506...
# Now concatenating chunk 507...
# Now concatenating chunk 508...
# Now concatenating chunk 509...
# Now concatenating chunk 510...
# Now concatenating chunk 511...
# Now concatenating chunk 512...
# Now concatenating chunk 513...
# Now concatenating chunk 514...
# Now concatenating chunk 515...
# Now concatenating chunk 516...
# Now concatenating chunk 517...
# Now concatenating chunk 518...
# Now concatenating chunk 519...
# Now concatenating chunk 520...
# Now concatenating chunk 521...
# Now concatenating chunk 522...
# Now concatenating chunk 523...
# Now concatenating chunk 524...
# Now concatenating chunk 525...
# Now concatenating chunk 526...
# Now concatenating chunk 527...
# Now concatenating chunk 528...
# Now concatenating chunk 529...
# Now concatenating chunk 530...
# Now concatenating chunk 531...
# Now concatenating chunk 532...
# Now concatenating chunk 533...
# Now concatenating chunk 534...
# Now concatenating chunk 535...
# Now concatenating chunk 536...
# Now concatenating chunk 537...
# Now concatenating chunk 538...
# Now concatenating chunk 539...
# Now concatenating chunk 540...
# Now concatenating chunk 541...
# Now concatenating chunk 542...
# Now concatenating chunk 543...
# Now concatenating chunk 544...
# Now concatenating chunk 545...
# Now concatenating chunk 546...
# Now concatenating chunk 547...
# Now concatenating chunk 548...
# Now concatenating chunk 549...
# Now concatenating chunk 550...
# Now concatenating chunk 551...
# Now concatenating chunk 552...
# Now concatenating chunk 553...
# Now concatenating chunk 554...
# Now concatenating chunk 555...
# Now concatenating chunk 556...
# Now concatenating chunk 557...
# Now concatenating chunk 558...
# Now concatenating chunk 559...
# Now concatenating chunk 560...
# Now concatenating chunk 561...
# Now concatenating chunk 562...
# Now concatenating chunk 563...
# Now concatenating chunk 564...
# Now concatenating chunk 565...
# Now concatenating chunk 566...
# Now concatenating chunk 567...
# Now concatenating chunk 568...
# Now concatenating chunk 569...
# Now concatenating chunk 570...
# Now concatenating chunk 571...
# Now concatenating chunk 572...
# Now concatenating chunk 573...
# Now concatenating chunk 574...
# Now concatenating chunk 575...
# Now concatenating chunk 576...
# Now concatenating chunk 577...
# Now concatenating chunk 578...
# Now concatenating chunk 579...
# Now concatenating chunk 580...
# Now concatenating chunk 581...
# Now concatenating chunk 582...
# Now concatenating chunk 583...
# Now concatenating chunk 584...
# Now concatenating chunk 585...
# Now concatenating chunk 586...
# Now concatenating chunk 587...
# Now concatenating chunk 588...
# Now concatenating chunk 589...
# Now concatenating chunk 590...
# Now concatenating chunk 591...
# Now concatenating chunk 592...
# Now concatenating chunk 593...
# Now concatenating chunk 594...
# Now concatenating chunk 595...
# Now concatenating chunk 596...
# Now concatenating chunk 597...
# Now concatenating chunk 598...
# Now concatenating chunk 599...
# Now concatenating chunk 600...
# Now concatenating chunk 601...
# Now concatenating chunk 602...
# Now concatenating chunk 603...
# Now concatenating chunk 604...
# Now concatenating chunk 605...
# Now concatenating chunk 606...
# Now concatenating chunk 607...
# Now concatenating chunk 608...
# Now concatenating chunk 609...
# Now concatenating chunk 610...
# Now concatenating chunk 611...
# Now concatenating chunk 612...
# Now concatenating chunk 613...
# Now concatenating chunk 614...
# Now concatenating chunk 615...
# Now concatenating chunk 616...
# Now concatenating chunk 617...
# Now concatenating chunk 618...
# Now concatenating chunk 619...
# Now concatenating chunk 620...
# Now concatenating chunk 621...
# Now concatenating chunk 622...
# Now concatenating chunk 623...
# Now concatenating chunk 624...
# Now concatenating chunk 625...
# Now concatenating chunk 626...
# Now concatenating chunk 627...
# Now concatenating chunk 628...
# Now concatenating chunk 629...
# Now concatenating chunk 630...
# Now concatenating chunk 631...
# Now concatenating chunk 632...
# Now concatenating chunk 633...
# Now concatenating chunk 634...
# Now concatenating chunk 635...
# Now concatenating chunk 636...
# Now concatenating chunk 637...
# Now concatenating chunk 638...
# Now concatenating chunk 639...
# Now concatenating chunk 640...
# Now concatenating chunk 641...
# Now concatenating chunk 642...
# Now concatenating chunk 643...
# Now concatenating chunk 644...
# Now concatenating chunk 645...
# Now concatenating chunk 646...
# Now concatenating chunk 647...
# Now concatenating chunk 648...
# Now concatenating chunk 649...
# Now concatenating chunk 650...
# Now concatenating chunk 651...
# Now concatenating chunk 652...
# Now concatenating chunk 653...
# Now concatenating chunk 654...
# Now concatenating chunk 655...
# Now concatenating chunk 656...
# Now concatenating chunk 657...
# Now concatenating chunk 658...
# Now concatenating chunk 659...
# Now concatenating chunk 660...
# Now concatenating chunk 661...
# Now concatenating chunk 662...
# Now concatenating chunk 663...
# Now concatenating chunk 664...
# Now concatenating chunk 665...
# Now concatenating chunk 666...
# Now concatenating chunk 667...
# Now concatenating chunk 668...
# Now concatenating chunk 669...
# Now concatenating chunk 670...
# Now concatenating chunk 671...
# Now concatenating chunk 672...
# Now concatenating chunk 673...
# Now concatenating chunk 674...
# Now concatenating chunk 675...
# Now concatenating chunk 676...
# Now concatenating chunk 677...
# Now concatenating chunk 678...
# Now concatenating chunk 679...
# Now concatenating chunk 680...
# Now concatenating chunk 681...
# Now concatenating chunk 682...
# Now concatenating chunk 683...
# Now concatenating chunk 684...
# Now concatenating chunk 685...
# Now concatenating chunk 686...
# Now concatenating chunk 687...
# Now concatenating chunk 688...
# Now concatenating chunk 689...
# Now concatenating chunk 690...
# Now concatenating chunk 691...
# Now concatenating chunk 692...
# Now concatenating chunk 693...
# Now concatenating chunk 694...
# Now concatenating chunk 695...
# Now concatenating chunk 696...
# Now concatenating chunk 697...
# Now concatenating chunk 698...
# Now concatenating chunk 699...
# Full dataset load complete

# %%
#print(reviews.shape) #(6990280, 9)

#preserving date column in case time-based analysis is relevant later
reviews = reviews.loc[:, ['stars', 'text', 'date']]
reviews
# Out:
#          stars                                               text  \
# 0            3  If you decide to eat here, just be aware it is...
# 1            5  I've taken a lot of spin classes over the year...
# 2            3  Family diner. Had the buffet. Eclectic assortm...
# 3            5  Wow!  Yummy, different,  delicious.   Our favo...
# 4            4  Cute interior and owner (?) gave us tour of up...
# ...        ...                                                ...
# 6990275      5  Latest addition to services from ICCU is Apple...
# 6990276      5  This spot offers a great, affordable east week...
# 6990277      4  This Home Depot won me over when I needed to g...
# 6990278      5  For when I'm feeling like ignoring my calorie-...
# 6990279      3  Located in the 'Walking District' in Nashville...
#
#                        date
# 0       2018-07-07 22:09:11
# 1       2012-01-03 15:28:18
# 2       2014-02-05 20:30:30
# 3       2015-01-04 00:01:03
# 4       2017-01-14 20:54:15
# ...                     ...
# 6990275 2014-12-17 21:45:20
# 6990276 2021-03-31 16:55:10
# 6990277 2019-12-30 03:56:30
# 6990278 2022-01-19 18:59:27
# 6990279 2018-01-02 22:50:47
#
# [6990280 rows x 3 columns]

# %%
#Takes about 47 seconds to write back out full dataset if you choose to do that
#reviews.to_csv("yelp_review_dataset_3col.csv")

# %% [markdown]
# ### Generate true sample of 100,000 reviews

# %%
yelp_true_sample = reviews.sample(n=100000, random_state=2023, replace=False)
yelp_true_sample.reset_index(drop=True, inplace=True)

#This file is about 59.8MB and takes ~1 second to write to file
yelp_true_sample.to_csv("yelp_true_sample_100k.csv")

# %% [markdown]
# ### Generate oversample with 20,000 reviews of each star rating

# %%
yelp_oversample = reviews.loc[(reviews.loc[:,'stars'] == 1), :].sample(n=20000, 
                                                                       random_state=2023, 
                                                                       replace=False)

for rating in range(2,6):
    yelp_oversample = pd.concat((yelp_oversample,
                                reviews.loc[(reviews.loc[:,'stars'] == rating), :].sample(n=20000, 
                                                                       random_state=2023, 
                                                                       replace=False)))
yelp_oversample.reset_index(drop=True, inplace=True)
yelp_oversample.to_csv("yelp_oversample_20k_per_rating.csv")

# %%
#testing whether oversample worked right
# for i in range(1,6):
#     print(yelp_oversample.loc[(yelp_oversample.loc[:,'stars'] == 5)].shape)
# Out:
# (20000, 3)
# (20000, 3)
# (20000, 3)
# (20000, 3)
# (20000, 3)
