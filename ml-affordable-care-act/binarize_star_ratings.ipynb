# %% [markdown]
# ### Determining binary classification of Yelp star reviews
# CAPP 30254: Machine Learning for Public Policy<br>
#
# **By:** Matt Jackson<br>
# _group members:_ Aïcha Camara, Rohit Kandala, Summer Long<br>
#
# Our project's final output will classify tweets about the Patient Protection and Affordable Care Act of 2010 ("Affordable Care Act", informally "Obamacare") as positive or negative. However, our training data -- customer reviews from Yelp.com -- uses ratings that are numeric (1 to 5 "stars"). In order to make apples-to-apples comparisons across the data sets, we need to ascertain where to create the cutoff in star ratings to produce a binary classification (or whether to do a ternary positive / neutral / negative classification, if data warrants that).

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk import FreqDist

import re

tokenizer = RegexpTokenizer(r'\w+')
STOPWORDS = set(stopwords.words('english'))

# %%
#Set filepath to match location on your machine
reviews = pd.read_csv("yelp_oversample_20k_per_rating.csv").drop("Unnamed: 0",
                                                                 axis=1)

#Create a sub-dataset for each star rating
#TODO: Variable assignment with loop determining number/star rating
reviews_1star = reviews.loc[(reviews.loc[:,'stars'] == 1), :].copy()
reviews_2star = reviews.loc[(reviews.loc[:,'stars'] == 2), :].copy()
reviews_3star = reviews.loc[(reviews.loc[:,'stars'] == 3), :].copy()
reviews_4star = reviews.loc[(reviews.loc[:,'stars'] == 4), :].copy()
reviews_5star = reviews.loc[(reviews.loc[:,'stars'] == 5), :].copy()

star_dfs = [reviews_1star, reviews_2star, reviews_3star, reviews_4star, reviews_5star]

# %% [markdown]
# My recommendation is informed by two methodologies: a more subjective analysis of the most common words at each star rating, and a more automated analysis of sentiment scores at the review level using the popular VADER toolkit.

# %% [markdown]
# ### Subjective most-common-words assessment
#
# We find the most common unique words in each star rating, perhaps filtering down to sentiment-inflected words, to see if we can intuit an apt cutoff value between star ratings.

# %%
#Consulted source: 
#https://www.geeksforgeeks.org/removing-stop-words-nltk-python/

def n_most(df, n):
    '''
    Get the n most common words in a dataframe of Yelp reviews.
    Excludes stopwords.

    Inputs:
        df (pandas DataFrame): set of Yelp reviews with 'text' column
        n (int): number of words you want

    Returns (nltk FreqDist): set of word-frequency tuples
    '''
    runon = ' '.join(df.loc[:,'text'])
    runon_tokens = tokenizer.tokenize(runon.lower())
    runon_destopped = out_stopwords(runon_tokens)
    return FreqDist(runon_destopped).most_common(n)

def out_stopwords(lst):
    '''
    Remove stopwords from a list of words.
    Input:
        lst (list of strings)
    Returns (lst): that string without stopwords
    '''
    return [word for word in lst if word not in STOPWORDS]

def nmost_unique_by_star(n, actually_unique=True):
    '''
    Find the words within the top n most common that are *unique* to each
    star rating.

    Inputs:
        -n (int): number for most common words (n=100 means it'll fetch the 100
        most common words from each star rating in the sample)
        
        -actually_unique (boolean): If True, return the words that occur only
        in a particular star rating and never occur in any other star rating.
        (e.g. for the 1-star reviews, return words that occur only in 1-star
        reviews, and not any other star rating.)
        If False, return all words that occur in a non-trivial subset of the
        star ratings (e.g. for the 1-star reviews, return words that occur 
        in up to four distinct star ratings, including 1-star, but not all five)
    Returns (?): some representation of most common unique words
    '''
    nmost_dict = {}
    for i, star_df in enumerate(star_dfs):
        nmost_freqs = n_most(star_df, n)
        nmost_words = [tuple[0] for tuple in nmost_freqs]
        #indices are star rating, NOT zero-based
        nmost_dict[i+1] = nmost_words

    n_in_common = set(nmost_dict[1]).intersection(set(nmost_dict[2]),
                                                          set(nmost_dict[3]),
                                                          set(nmost_dict[4]),
                                                          set(nmost_dict[5]))
    
    if actually_unique:
        top_n_unique = {}
        top_n_unique[1] = set(nmost_dict[1]) - set(nmost_dict[2]) - set(nmost_dict[3]) - set(nmost_dict[4]) - set(nmost_dict[5])
        top_n_unique[2] = set(nmost_dict[2]) - set(nmost_dict[1]) - set(nmost_dict[3]) - set(nmost_dict[4]) - set(nmost_dict[5])
        top_n_unique[3] = set(nmost_dict[3]) - set(nmost_dict[1]) - set(nmost_dict[2]) - set(nmost_dict[4]) - set(nmost_dict[5])
        top_n_unique[4] = set(nmost_dict[4]) - set(nmost_dict[1]) - set(nmost_dict[2]) - set(nmost_dict[3]) - set(nmost_dict[5])
        top_n_unique[5] = set(nmost_dict[5]) - set(nmost_dict[1]) - set(nmost_dict[2]) - set(nmost_dict[3]) - set(nmost_dict[4])

        return top_n_unique

    else:
        top_n_notallshared = {k: {word for word in v if word not in n_in_common}
                              for k,v in nmost_dict.items()}
        return top_n_notallshared

# %%
#Testing different settings for n to see which one comes up with a manageable set
#of words to assess.

#genuinely unique words
SETTINGS_FOR_N = [10, 50, 100, 500, 1000, 2000, 5000]

print("Truly unique words by star rating:")
for setting in SETTINGS_FOR_N:
    print(f"\nAmong top {setting}")
    nmost_string = str(nmost_unique_by_star(setting))
    print(re.sub(r' ([0-9]):', r'\n\1:', nmost_string))

#non-unique
print("\nFound at this star rating, but not all others:")
for setting in SETTINGS_FOR_N:
    print(f"\nAmong top {setting}")
    nmost_string = str(nmost_unique_by_star(setting, actually_unique=False))
    print(re.sub(r' ([0-9]):', r'\n\1:', nmost_string))
# Out:
# Truly unique words by star rating:
#
# Among top 10
# {1: {'never'},
# 2: set(),
# 3: set(),
# 4: {'really'},
# 5: {'go', 'best'}}
#
# Among top 50
# {1: {'car', 'give', 'still', 'called', 'left', 'manager', 'call', 'take', 'customer'},
# 2: set(),
# 3: {'ok', 'think', '3', 'though'},
# 4: {'night', 'area'},
# 5: {'amazing', 'every', 'everything', 'recommend', 'excellent', 'new'}}
#
# Among top 100
# {1: {'worst', 'waiting', 'put', 'someone', 'away', 'rude', 'business', 'pay', 'car', 'called', '30', 'horrible', 'store', 'company', 'hour', 'done', 'later', 'terrible', 'manager', 'call', 'phone', 'customer', 'money'},
# 2: {'disappointed', 'waitress', 'server', 'long'},
# 3: {'stars', 'decent'},
# 4: {'fried', 'hot', 'enjoyed', 'tasty', 'beer', 'fries'},
# 5: {'worth', 'awesome', 'loved', 'highly', 'every', 'visit', 'find', 'coffee', 'years', 'spot', 'looking', 'wonderful', 'family', 'perfect', 'clean', 'favorite', 'feel', 'super'}}
#
# Among top 500
# {1: {'returned', 'insurance', 'answer', 'treated', 'number', 'disgusting', 'website', 'month', 'calls', 'sales', 'placed', 'lost', 'purchased', 'unprofessional', 'turned', 'explained', 'sign', 'issues', 'talk', 'credit', 'closed', 'worse', 'move', 'zero', 'taken', 'speak', 'save', 'stated', 'email', 'nail', 'situation', 'fix', 'refused', 'oil', 'mins', 'truck', 'talking', 'leaving', 'spent', 'changed', 'sent', 'establishment', 'spoke', 'attitude', 'send', 'showed', 'weeks', 'elsewhere', 'employee', 'waste', 'min', 'total', 'telling', '40', 'checked', 'contact', 'reservation', 'somewhere', 'supposed', 'avoid', 'says', 'man', 'vehicle', 'woman', 'read', 'asking', 'response', 'refund', 'mistake', 'hold', 'multiple', 'dollars', 'online', 'hear', 'minute', 'clearly', '25', 'bought'},
# 2: {'rest', 'medium', 'noticed', 'barely', 'honestly', 'overpriced', 'pieces', 'hostess', 'glass'},
# 3: {'miss', 'appetizers', 'taco', 'standard', 'near'},
# 4: {'packed', 'neighborhood', 'date', 'specials', 'garlic', 'surprised', 'sausage', 'ambiance', 'located', 'outdoor', 'patio', 'downtown', 'friday', 'oysters', 'chinese'},
# 5: {'thanks', 'team', 'lovely', 'dr', 'tour', 'within', 'incredible', 'nashville', 'worked', 'recommended', 'ingredients', 'professional', 'salon', 'reno', 'recently', 'outstanding', 'wedding', 'questions', 'tampa', 'fabulous', 'welcoming', 'birthday', 'thank', 'accommodating', 'hands', 'forward', 'across', 'helped', 'exactly', 'beyond', 'visiting', 'gem', 'truly', 'chef', 'knowledgeable', 'vegan', 'daughter', 'process', 'world', 'wow'}}
#
# Among top 1000
# {1: {'question', 'member', 'threw', 'tires', 'insurance', 'treatment', 'damage', '000', 'rent', 'calls', 'account', 'bank', 'everywhere', 'apartment', 'communication', 'cover', 'sold', 'answered', 'driver', 'unprofessional', 'warranty', 'talked', 'sense', 'favor', 'figure', 'policy', 'sale', 'filthy', 'zero', 'package', 'crap', 'stating', 'property', 'explain', 'assured', 'dont', '60', 'scam', 'dealership', 'prior', 'quote', 'text', 'health', 'stated', 'email', 'gel', 'scheduled', 'wearing', 'sick', 'follow', 'miles', 'cause', 'putting', 'department', 'allowed', 'unit', 'polish', 'broken', 'didnt', 'shower', 'refused', 'nobody', 'rental', 'interested', 'story', 'poorly', 'contacted', 'furniture', 'dress', 'machine', 'eyes', 'promised', 'closing', 'test', 'sucks', 'suggest', 'mother', 'cancel', 'proceeded', 'groupon', 'straight', 'spoke', 'mail', 'calling', '18', 'tech', 'booked', 'handle', '24', 'living', 'mask', 'drove', 'maintenance', 'parts', 'discount', 'garbage', 'began', 'address', 'nasty', 'tire', 'security', 'excuse', 'driving', 'agreed', 'joke', 'cars', 'hung', 'additional', 'deposit', 'brand', 'sister', 'doors', 'contact', 'ignored', 'feet', 'fault', 'continued', 'dollar', 'dead', '0', 'following', 'picture', 'vehicle', 'tells', 'replaced', 'toilet', 'refund', 'upset', 'message', 'post', 'ten', 'replace', 'ruined', 'costs', 'broke', 'charges', 'women', 'doctor', 'beware', '35', 'apology', 'hell', 'unacceptable', 'information', 'stuck', 'contract', 'children', 'cancelled', 'deliver', 'corporate', 'trash', 'complained', 'u', 'payment'},
# 2: {'flavorless', 'plastic', 'brown', 'imagine', 'rushed', '14', 'patrons', 'chewy', 'raw', 'stale', 'tasteless', 'sub', 'soda', 'refill', 'uncomfortable', 'annoyed', 'menus'},
# 3: {'margarita', 'personally', 'pad', 'bites', 'known', 'alright', 'older', '99', 'hype', 'generally', 'hopefully'},
# 4: {'hummus', 'apple', 'watching', 'upstairs', 'offers', 'korean', 'pot', 'po', 'quarter', 'peppers', 'buffalo', 'dumplings', 'crawfish', 'greek', 'honey', 'popular', 'greens', 'waffle', 'weekends', 'playing', 'strip', 'tap', 'weather', 'bars', 'hang', 'iced', 'tofu', 'pleasantly', 'crisp', 'sized', 'rib', 'walls', 'station', 'selections', 'surprisingly', 'opted', 'mushroom', 'pub', 'bourbon', 'bean', 'enjoyable', 'guacamole', 'larger', 'noodle'},
# 5: {'latte', 'lucky', 'heart', 'omg', 'garden', 'santa', 'team', 'strawberry', 'personable', 'thorough', 'continue', 'smile', 'whenever', 'gym', 'cuisine', 'gluten', 'detail', 'daily', 'country', 'barbara', 'art', 'courteous', 'baby', 'tons', 'loves', 'safe', 'superb', 'welcome', 'throughout', 'indy', 'fabulous', 'fit', 'become', 'polite', 'bakery', 'filet', 'met', 'relaxing', 'funny', 'kick', 'meet', 'die', 'terrific', 'finding', 'owned', 'refreshing', 'appreciated', 'staying', 'moment', 'recommendation', 'gorgeous', 'history', 'creative', 'heaven', 'regret', 'products', 'moist', 'notch', 'pleasure', 'shops', 'pricing', 'phenomenal', 'hidden', 'recommendations', 'honest', 'prompt', 'exceptional', 'classes', 'cookies'}}
#
# Among top 2000
# {1: {'pa', 'concern', 'argue', 'incorrect', 'pharmacy', 'rudely', 'claim', 'license', 'installation', 'bugs', 'clue', 'damage', '000', 'clerk', 'lied', 'laughed', 'racist', 'fucking', 'states', 'shirt', 'nightmare', 'emailed', 'advise', 'record', 'required', 'gloves', 'communication', 'switch', 'shut', 'depot', 'apartments', 'representative', 'ill', 'dealer', 'managers', 'mistakes', 'animal', 'earned', 'warranty', 'keys', '2020', 'forth', 'shipping', 'safety', '2019', 'inconvenience', 'canceled', 'declined', 'buyer', 'jobs', 'condition', 'phones', 'hurt', 'emails', 'lease', 'reach', 'x', 'crappy', 'human', 'stating', 'hospital', 'courtesy', 'computer', 'install', 'police', 'salesman', 'parked', 'mechanic', 'assured', 'sheets', 'embarrassed', 'coat', 'heater', 'frame', 'scam', 'medical', 'express', 'confirmed', 'yelling', 'screwed', 'deserve', 'text', 'dealt', 'false', 'poisoning', 'kidding', 'responsibility', 'questioned', 'straw', '2016', 'agent', 'neighbors', 'bs', 'behavior', 'dealing', 'sink', 'power', 'written', 'excuses', 'male', 'handled', 'fees', 'coupons', 'ceiling', 'numbers', 'disrespectful', 'billing', 'unit', 'rep', 'damaged', 'ignore', 'incident', 'june', 'tone', 'tub', 'news', 'labor', 'ripped', 'arriving', 'rental', 'receiving', 'loan', 'ups', 'contacted', 'boss', 'incompetent', 'repaired', '500', 'tank', 'dump', 'voicemail', 'lesson', 'id', 'pissed', 'causing', 'patients', 'letting', 'voice', 'trade', 'january', 'november', 'warning', 'december', 'leaking', 'promised', '28', 'reported', 'answers', 'approached', 'accept', 'father', 'exchange', 'unhappy', 'honor', 'exam', 'mail', 'unpleasant', 'advised', 'cell', '22', 'shuttle', 'april', 'confirm', 'reschedule', 'stains', 'appt', 'pathetic', 'wasting', 'respond', 'gate', 'currently', 'assistance', 'rented', 'denied', 'warned', 'video', 'politely', 'planned', 'unhelpful', 'companies', 'wtf', 'attempted', 'shady', 'leak', 'trained', 'comments', 'march', 'july', 'condescending', 'er', 'garbage', 'bbb', 'interest', 'model', 'whatsoever', 'associate', 'walmart', 'claimed', 'screw', 'disaster', 'info', 'quoted', 'reached', 'regarding', 'btw', 'doctors', 'status', 'client', 'resolve', 'report', 'explaining', 'dirt', 'copy', 'reserved', 'confirmation', 'discuss', 'blame', 'risk', '400', 'hung', 'fired', 'entirely', 'holding', 'deposit', 'angry', '300', 'entered', 'reply', 'prescription', 'insisted', 'supervisor', 'forced', 'battery', 'refunded', 'whoever', 'cared', 'engine', 'initial', 'google', 'cab', 'repeatedly', '26', 'ac', 'practices', 'couch', 'transferred', 'sending', 'dishonest', 'starts', 'purchasing', '150', 'emergency', 'claims', 'letter', 'frustrated', 'disgusted', 'ship', 'nurse', 'answering', 'encountered', 'lying', 'code', 'lie', 'file', 'membership', 'horrendous', 'signed', '70', 'screaming', 'mold', 'messages', 'loyal', 'yelled', 'according', 'wrote', 'falling', 'drivers', 'error', 'suck', 'argued', 'refuse', 'internet', 'page', 'explanation', 'construction', 'toyota', 'locked', 'rip', 'shift', 'contract', 'paperwork', 'cancelled', 'skills', 'august', 'caused'},
# 2: {'saving', 'starving', 'sloppy', 'lackluster', 'luke', 'spoiled', 'description', 'grace', 'runny', 'watered', 'bitter', 'wondering', 'chatting', 'utensils', 'pour', 'fishy', 'oz', 'tab', 'lastly', 'ugh', 'disappeared', 'practically', 'rubbery', 'ends', 'tag', 'staffed', 'happening', 'lukewarm', 'bits', 'poured', 'rack', 'refilled', 'overrated', 'forgotten', 'greet', 'canned'},
# 3: {'quantity', 'mainly', 'exciting', 'scoop', 'hoped', 'wing', 'improved', 'necessarily', 'hibachi', 'bummer', 'blow', 'exception', 'pan', 'flatbread', 'bet', 'factor', 'appears', 'terminal', 'pat', 'improvement', 'convenience', 'diet', 'steep', 'compare', 'dated', 'adequate', 'hipster', 'clam', 'cramped', 'confusing', 'lately'},
# 4: {'names', 'cheeses', 'alternative', 'con', 'downside', 'diverse', 'dancing', 'courtyard', 'carrot', 'minor', 'darn', 'includes', 'peas', 'chinatown', 'protein', 'lively', 'spanish', 'hearty', 'headed', 'tart', 'corned', 'sesame', 'ipa', 'brews', 'entertainment', 'creole', 'root', 'movies', 'staple', 'funky', 'brick', 'bang', 'breaded', 'sliders', 'olives', 'beverages', 'fitness', 'assortment', 'feed', 'sweetness', 'trail', 'wraps', 'reminds', 'eats', 'stocked', 'familiar', 'tucked', 'played', 'crowds', 'aioli', 'sampler', 'smells', 'kale', 'guac', 'adult', 'nyc', 'peach', 'stage', 'ale'},
# 5: {'highlights', 'genuinely', 'holy', 'tours', 'secret', 'chefs', 'thankful', 'tooth', 'anniversary', 'saved', 'dental', 'genuine', 'tree', 'pride', 'collection', 'salons', 'michael', 'delight', 'cats', 'describe', 'cupcake', 'raspberry', 'rose', 'happier', 'earth', 'county', 'regulars', 'talented', 'neck', 'grew', 'mile', 'studio', 'vintage', 'beignets', 'poke', 'kevin', 'jewelry', 'traveling', 'divine', 'blast', 'artist', 'kudos', 'energy', 'knowledgable', 'los', 'pleasure', 'ways', 'treasure', 'planning', 'hooked', 'chris', 'hospitality', 'whiskey', 'dream', 'legit', 'amazed', 'chat', 'nicest', 'lives', 'remembered', 'runs', 'samples', 'listened', 'cuts', 'killer', 'stumbled', 'professionalism', 'created', 'deserves', 'grateful', 'compliments', 'weekly', 'welcomed', 'amazingly', 'thrilled', 'golden', 'yoga', 'penny', 'gifts', 'colors', 'adorable', 'thorough', 'facial', 'soooo', 'trees', 'matt', 'personality', 'tom', 'workout', 'plants', 'steve', 'risotto', 'stl', 'celebrate', 'stress', 'hesitate', 'wax', 'pets', 'create', 'custom', 'everyday', 'champagne', 'exceeded', 'brother', 'program', 'nervous', 'impeccable', 'sooo', 'informative', 'edmonton', 'knowledge', 'dave', 'david', 'importantly', 'ease', 'timely', 'worried', 'clearwater', 'books', 'guide', 'caring', 'magic', 'rocks', 'mike'}}
#
# Among top 5000
# {1: {'cancelling', 'approved', 'alert', 'uhaul', 'funeral', 'flooded', 'liar', 'responds', 'inept', 'void', 'issued', 'flooring', 'feces', 'ants', 'permission', 'financial', 'african', 'tactics', 'evidently', 'thieves', 'pitch', 'blocked', 'offensive', 'valued', 'tags', 'trashy', 'screws', 'verify', 'unethical', 'diagnostic', 'damages', 'scanned', 'vacuumed', 'situations', 'disabled', 'registration', 'leasing', 'seller', 'ordeal', 'authorized', 'transmission', 'cheated', 'phoned', 'resulting', '8th', 'unapologetic', 'valve', 'anger', 'unsanitary', 'chemicals', 'refuses', 'dept', 'plague', 'cigarettes', 'bouncers', 'aug', '140', 'foreign', 'hose', 'comcast', 'disease', 'bumper', 'sandy', 'reporting', 'dresser', 'federal', 'aggressively', 'mental', 'waive', '37', 'mileage', 'displeasure', 'va', 'exaggerating', 'inconsiderate', 'determine', 'verified', 'abruptly', 'utter', 'healthcare', 'endure', 'slipped', 'bitch', 'stealing', 'inspector', 'treating', 'mgr', 'tenant', 'usps', 'benefits', 'domino', 'recieved', 'monitor', 'inconvenienced', 'toll', 'patch', 'corporation', 'blanket', 'abc', 'sends', 'hostage', 'bolt', 'hertz', 'discrimination', 'veterans', 'illegal', 'physician', 'departure', 'resolution', 'director', 'canceling', 'whats', '1200', 'spouse', 'lip', 'recorded', 'manufacturer', 'existing', 'prescribed', 'bureau', 'hoa', 'leo', 'bullshit', 'dentists', 'documents', 'sarcastic', 'printing', 'incompetence', 'refunds', 'dispute', '9th', 'gps', 'assembly', 'pipe', 'lawyer', 'inefficient', 'unreliable', 'cheat', 'picks', 'laying', 'rx', 'hazard', 'fraud', 'infected', 'crooked', 'feb', 'guessed', 'criminal', 'deny', 'acknowledging', 'airline', 'johns', 'landlord', 'instructed', 'handles', 'dominos', 'auction', 'defensive', 'enterprise', 'notifying', 'cop', 'rights', 'begins', '350', 'chart', 'authority', 'racist', 'fucking', 'switching', 'headaches', 'scratching', 'inaccurate', 'unavailable', 'scammed', 'toilets', 'meds', 'argumentative', 'teenage', 'jan', 'audacity', 'tested', 'redone', 'survey', 'insisting', 'commission', 'blind', '1500', 'motor', 'scum', 'licensed', 'yr', 'confronted', 'causes', 'scratches', 'laws', 'valid', 'officer', 'hates', 'adt', 'communicating', 'agency', 'bid', 'reconsider', 'passengers', '33', 'batteries', '1800', 'crooks', 'cough', 'kia', 'mandatory', 'drawers', 'papers', 'submit', 'suffice', '6th', 'exhaust', 'sprayed', 'handicapped', 'rescheduled', 'taped', 'fax', 'gsr', 'eddie', 'drug', 'dodge', 'pipes', 'measurements', 'loan', 'mirrors', 'ace', 'representatives', 'reps', 'hygiene', 'hyundai', 'lube', 'collections', 'slip', 'reaching', 'cockroach', 'mercedes', 'pages', 'unresponsive', 'fedex', 'release', 'moldy', 'pulls', 'insulting', 'flush', 'payments', 'bees', 'taxes', 'openly', 'inspect', 'president', 'stolen', 'doordash', 'promo', 'discussing', 'furthermore', 'waist', 'deplorable', 'radiator', 'operator', 'invoice', 'weed', '180', 'drugs', 'camper', 'data', 'scammers', 'trimmed', 'automated', 'refusing', 'verizon', 'robbed', 'evidence', 'managing', 'ventilation', 'furnace', 'demanded', 'remainder', 'sept', 'idiots', 'passenger', 'vw', 'gallon', 'ruining', 'capable', 'notify', 'argument', 'loading', 'telephone', 'personnel', 'government', 'ethics', 'click', 'reimbursed', 'decides', 'hvac', 'doesnt', 'actions', 'united', 'accused', 'disregard', 'electrical', 'magically', 'suffering', 'disposal', 'forbid', 'indicating', 'chin', '59', 'notification', 'privacy', 'permit', 'deleted', 'cabinet', 'disgust', 'outright', 'reimbursement', 'alternator', 'exhausted', 'accepting', 'memorial', 'manners', 'steering', 'cracks', 'employed', 'faucet', 'embarrassment', 'responding', 'bat', 'cc', 'attorney', 'costumer', 'advertisement', 'compressor', 'renting', 'mailbox', 'filters', 'contractors', 'chemical', 'forty', 'backs', 'defective', 'shocking', 'diagnose', 'rectify', 'diarrhea', 'interview', 'audi', 'clogged', 'trunk', 'wth', 'empathy', 'towing', 'prepaid', 'screamed', 'bent', 'mechanical', '08', 'inexcu ...
# 2: {'watches', 'unlikely', 'shaker', 'curt', 'crossed', 'upcharge', 'acai', 'maid', 'bagged', 'goodwill', 'premade', 'skins', 'minded', 'unaware', 'inconveniencing', 'fairness', 'hardware', 'rung', 'dull', 'unappealing', 'roadhouse', 'gum', 'msg', 'audience', 'drowning', 'annoyance', 'pike', 'ft', 'reheat', 'absent', 'resulted', 'sore', 'slapped', 'gristle', 'imitation', 'hmm', 'unimpressive', 'hopeful', 'skipping', 'brag', 'pillow', 'overhaul', 'vent', 'petty', 'nada', 'nursing', 'chopsticks', 'avocados', '44', 'continually', 'elbow', 'yams', 'overworked', 'overlook', 'smoker', 'painfully', 'rag', 'cesar', 'americano', 'dusty', 'cadillac', 'sober', 'biggie', 'enthusiasm', 'labels', 'jerky', 'asia', '3x', 'figuring', '7am', 'disinterested', 'dissapointed', 'depressing', '51', 'palatable', 'marginal', 'shellac', 'silence', 'rubbed', 'humid', 'specified', 'masseuse', 'chang', 'busser', 'dismal', 'soupy', 'hooters', 'stink', 'snotty', 'oldest', 'largely', 'blocking', 'bleh', 'defense', 'unbearable', 'turnover', 'miscommunication', 'chipping', 'pf', 'unfamiliar', 'knives', 'guinness', 'whopping', 'swallow', 'bro', 'begging', 'carryout', 'failing', 'blasting', 'gap', 'crumbled', 'nickel', 'mediocrity', 'uninterested', 'carnival', 'inflated'},
# 3: {'sage', 'heels', 'slim', 'yelper', 'cowboy', 'freeway', 'designated', 'contents', 'invest', 'legacy', 'abundant', 'acidic', 'pedestrian', 'wit', 'queue', 'curb', 'anyhow', 'pong', 'flounder', 'rows', 'supreme', 'scallions', 'fresco', 'katrina', 'neighboring', 'rank', 'oregano', 'bothers', 'wheelchair', 'boo', 'sufficient', 'se', 'petite', 'tin', 'rooster', 'aspects', 'hue', 'yards', 'samosa', 'carolina', 'specialize', 'fu', 'theory', 'sums', 'decoration', 'accustomed', 'sonic', 'cantina', 'descent', 'landmark', 'extras', 'jones', 'outs', 'jumping', 'kroger', 'moisture', 'strangely', 'geared', 'respectable', 'chalkboard', 'varies', 'irritating', 'shoppers', 'grapefruit', 'glory', 'tl', 'digress', 'scarce', 'singer', 'critical', 'scored', 'performing', 'teeny', 'suited', 'gambling', 'electronic', 'flakes', 'distinct', 'misses', 'piccata', 'inclined', 'sweetened', 'whereas', 'verdict', 'dynasty', 'element', 'ripe', 'absinthe', '90s', 'slots', 'steady', 'sounding', 'carbonara', 'disappear', 'impressions', 'pate', 'breaker', 'wok', '80s', 'pictured', 'peppermill', 'enjoyment', 'amc', 'sport', 'dispenser', 'tails', 'oriental', 'barrier'},
# 4: {'overhead', 'crossing', 'et', 'oils', 'candies', 'fancier', 'aforementioned', 'wins', 'malaysian', 'snag', 'roomy', 'japan', 'wilmington', 'rotisserie', 'pbr', 'hong', 'hiking', 'crawl', 'bayou', 'chutney', 'cherries', 'taqueria', 'lager', 'septa', 'comedy', 'steaming', 'wee', 'soccer', 'revisit', 'posters', 'visually', 'cali', 'wednesdays', 'worries', 'sheraton', 'dosa', 'comfortably', 'iconic', 'guava', 'und', 'claws', 'korma', 'scotch', 'palette', 'kop', 'cashew', 'kiddos', 'scrapple', 'delightfully', 'pinot', 'kettle', 'boardwalk', 'region', 'legendary', 'plump', 'cuisines', 'memorabilia', 'infamous', 'pine', 'landed', 'specialties', 'voodoo', 'jukebox', 'mochi', 'carousel', 'plush', 'musicians', 'raisins', 'hanger', 'moscow', 'garlicky', 'clayton', 'cure', 'mansion', 'shine', 'parsley', 'craziness', 'wegmans', 'skate', 'flavours', 'marathon', 'tennis', 'surroundings', 'remoulade', 'complemented', 'sabrina', 'cured', 'height', 'fixings', 'savor', 'newest', 'variations', 'tostada', 'usf', 'sauerkraut', 'boozy', 'toro', 'maryland', 'tummy', 'smash', 'samosas', 'peppery', 'pomegranate', 'quest', 'brownies', 'camping', 'bursting', 'poppers', 'stalls', 'proteins', 'outlet', 'errands', 'tunes', 'chickpeas', 'pb', 'influence', 'melty', 'kiosk', 'louie', 'swanky', 'nostalgic', 'kong', 'feeding', 'entrées', 'british', 'intrigued', 'omelets', 'mae', 'tandoori', 'intrusive', 'flea', 'honeymoon', 'vote', 'mighty', 'deter', 'storefront', 'seed', 'darker', 'travelers', 'toffee', 'fri', 'carries', 'condensed', 'harrah', 'definately', 'almonds', 'paradise', 'nestled', 'dressings', 'opentable', 'volcano', 'criticism', 'spicier', 'faux', 'shore', 'spain', 'boar', 'musical', 'growler', 'airports', 'rotate', 'tiger', 'madness', 'consume', 'peeps', 'intriguing', 'puffs', 'baba', 'mores', 'coma', 'grapes', 'monkey', 'tracks', 'fixe', 'filipino', 'willie', 'taro', 'stumble', 'farmer', 'layered', 'hotdog', 'tabasco', 'consumed', 'thursdays', 'additions', 'chester', 'pancetta', 'snap', 'umbrellas', 'rigatoni', 'england', 'downsides', 'rail', 'habit', 'kobe', 'domestic', 'canadian', 'étouffée', 'viet', 'ritz', 'gathering', 'worthwhile', 'brim', 'yup', 'plum'},
# 5: {'mrs', 'nicole', 'bros', 'transition', 'floats', 'compelled', 'freakin', 'glowing', 'tint', 'solved', 'automotive', 'painless', 'personalized', 'sunglasses', 'greets', 'memphis', 'overdue', 'steven', 'artistic', 'debbie', 'manayunk', 'intimidating', 'haunted', 'efficiently', 'emily', 'chiropractor', 'effective', 'pairings', 'praise', 'redfish', 'parlor', 'cheery', 'dedication', 'society', 'condo', 'rachel', 'existed', 'hometown', 'vietnam', 'dolphins', 'farms', 'da', 'educated', 'warmth', 'toasty', 'floral', 'meticulous', 'macaroons', 'commander', 'cellar', 'barbershop', 'hattie', 'angelo', 'poses', 'jamie', 'rosa', 'magnificent', 'turf', 'relaxation', 'granite', 'ink', 'residential', 'anna', 'jordan', 'immensely', 'gosh', 'workouts', 'foodies', 'pennsylvania', 'ryan', 'aaron', 'soooooo', 'stephen', 'anxiety', 'defiantly', 'zahav', 'baskets', 'z', 'ann', 'passport', 'pokemon', 'porterhouse', 'phil', 'bday', 'easiest', 'daddy', 'surprises', 'magazines', 'haircuts', 'expertly', 'elizabeth', 'luxurious', 'joining', 'bobby', 'shortcake', 'adjustments', 'greg', 'taught', 'recovery', 'tommy', 'bakeries', 'tastiest', 'cannolis', 'stronger', 'ted', 'charts', 'keith', 'cocoa', 'amanda', 'kindness', 'visual', 'susan', 'accomodating', 'lauren', 'healing', 'imagined', 'kitty', 'barbers', 'passionate', 'thomas', 'rick', 'kevin', 'miami', 'climbing', 'ceremony', 'jenny', 'elegance', 'serene', 'muscle', 'woods', 'stones', 'sunshine', 'megan', 'therapists', 'official', 'maria', 'swamp', 'photography', 'distillery', 'smog', 'soothing', 'awe', 'skill', 'trainer', 'graciously', 'meridian', 'tremendously', 'glorious', 'exercises', 'elvis', 'capture', 'skilled', 'natalie', 'peter', 'poblano', 'searched', 'sf', 'peruvian', 'shooting', 'communicated', 'lessons', 'gary', 'heartbeat', 'andrew', 'hygienist', 'focaccia', 'piercing', 'phoenix', 'advanced', 'toy', 'considerate', 'laura', 'trustworthy', 'outcome', 'linda', 'missouri', 'daycare', 'jewelers', 'shawn', 'stephanie', 'safely', 'charcoal', 'lexus', 'jennifer', 'pleasurable', 'professionals', 'jose', 'cindy', 'recognized', 'facials', 'protocols', 'hardest', 'blessed', 'gentle', 'tailor', 'bern', 'expertise', 'angeles', 'sarah', 'designs', 'compassionate', 'orlando', 'technique', 'crema', 'kate', 'austin', 'courtney', 'bookstore', 'lick', 'richard', 'joey', 'nina', 'katie', 'flawless', 'phillies', 'curated', 'guides', 'breathtaking', 'indecisive', 'pierced', 'biased', 'assisted', 'transported', 'cemetery', 'bow', 'zach', 'overs', 'nailed', 'beth', 'celebrated', 'chapel', 'rob', 'brentwood', 'plantain', 'tina', 'league', 'crumb', 'coloring', 'beloved', 'sara', 'graduation', 'nancy', 'pairs', 'getaway', 'styled', 'brilliant', 'photographer', 'cotton', 'attractions', 'eric', 'candied', 'pressured', 'justice', 'virginia', 'professionally', 'montecito', 'jared', 'paris', 'jokes', 'hawaii', 'christine', 'sean', 'trainers', 'piercings', 'pampered', 'century', 'calming', 'cutest', 'es', 'seamless', 'randy', 'upcoming', 'appreciative', 'unbeatable', 'heather', 'truffles', 'tremendous', 'sunrise', 'tyler', 'hosted', 'realtor', 'projects', 'mouthwatering', 'weddings', 'taylor', 'coolest', 'kabobs', 'judy', 'ensured', 'timer', 'sweetest', 'freeze', 'puerto', 'wellness', 'developed', 'jason', 'curls', 'vine', 'jen', 'marble', 'lbs', 'faves', 'talent', 'science', 'surpassed', 'creates', 'versed', 'leche', 'cooling', 'appreciation', 'licked', 'usa', 'ken', 'dreaming', 'marvelous', 'opinions', 'dreams', 'kyle', 'mimi', 'styling', 'arts', 'daniel', 'princess', 'op', 'devour', 'listens', 'jewel', 'unwind', 'george', 'progress', 'travis', 'excellence', 'artisan', 'tiffany', 'technology', 'jake', 'chelsea', 'fur', 'jay', 'supportive', 'diego', 'engaged', 'beard', 'imported', 'melissa', 'adam', 'travels', 'fishing', 'techniques', 'rebecca', 'unforgettable', 'commitment', 'molly', 'shall', 'sweetheart', 'suburbs', 'climb'}}
#
# Found at this star rating, but not all others:
#
# Among top 10
# {1: {'get', 'like', 'would', 'never', 'back'},
# 2: {'get', 'good', 'like', 'would', 'back'},
# 3: {'great', 'get', 'good', 'like', 'would'},
# 4: {'great', 'get', 'good', 'really', 'like'},
# 5: {'great', 'good', 'go', 'best', 'back'}}
#
# Among top 50
# {1: {'still', 'another', 'asked', 'day', 'told', 'way', 'car', 'people', 'order', 'called', 'could', 'minutes', 'two', 'said', 'ever', 'took', 'know', 'never', 'bad', 'going', 'experience', 'give', 'left', 'manager', 'call', 'make', 'take', '2', 'customer'},
# 2: {'great', 'another', 'asked', 'well', 'told', 'better', 'way', 'people', 'order', 'staff', 'could', 'minutes', 'two', 'table', 'said', 'took', 'pretty', 'bar', 'restaurant', 'know', 'never', 'bad', 'chicken', 'menu', 'much', 'going', 'experience', 'nice', '2'},
# 3: {'sauce', 'great', 'little', '3', 'bit', 'well', 'better', 'way', 'people', 'order', 'staff', 'could', 'two', 'table', 'think', 'bar', 'pretty', 'restaurant', 'cheese', 'though', 'chicken', 'menu', 'much', 'try', 'nice', 'friendly', '2', '5', 'ok'},
# 4: {'sauce', 'great', 'little', 'definitely', 'bit', 'well', 'people', 'order', 'love', 'night', 'always', 'staff', 'could', 'bar', 'pretty', 'restaurant', 'cheese', 'best', 'delicious', 'area', 'chicken', 'menu', 'much', 'try', 'nice', 'friendly', '5', 'made', 'fresh'},
# 5: {'great', 'amazing', 'every', 'little', 'definitely', 'day', 'well', 'new', 'love', 'everything', 'always', 'staff', 'ever', 'excellent', 'restaurant', 'best', 'never', 'delicious', 'chicken', 'menu', 'much', 'experience', 'try', 'nice', 'friendly', 'make', 'made', 'fresh', 'recommend'}}
#
# Among top 100
# {1: {'worst', 'put', 'waiting', 'someone', 'still', 'wanted', 'another', '3', 'asked', 'away', 'rude', 'business', 'say', 'told', 'pay', 'car', 'location', 'next', 'called', '30', '1', 'horrible', 'minutes', 'said', 'table', 'store', '4', 'ever', 'since', 'took', 'room', 'times', 'company', 'last', '10', 'hour', 'nothing', 'done', 'work', 'bad', 'home', 'later', 'terrible', 'give', 'left', 'manager', 'call', '2', 'phone', 'customer', 'money'},
# 2: {'sauce', 'sure', 'meal', 'many', 'still', 'wanted', 'another', '3', 'asked', 'little', 'say', 'told', 'salad', 'location', 'small', 'something', 'price', 'next', '1', 'minutes', 'eat', 'table', 'said', 'since', 'think', 'took', 'pretty', 'bar', 'waitress', 'times', 'room', 'last', 'cheese', 'disappointed', 'nothing', '10', 'best', 'though', 'bad', 'drinks', 'menu', 'however', 'give', 'left', 'try', 'nice', '2', 'pizza', 'long', 'ok', 'server'},
# 3: {'sauce', 'sure', 'meal', 'side', 'many', 'still', 'stars', 'little', '3', 'another', 'definitely', 'say', 'bit', 'salad', 'small', 'location', 'price', 'something', 'love', 'always', 'minutes', 'overall', 'eat', 'decent', 'table', 'said', 'lot', 'since', 'think', 'bar', 'pretty', 'lunch', 'took', 'times', 'room', 'cheese', 'nothing', 'though', 'best', 'bad', 'drinks', 'area', 'menu', 'however', 'give', 'try', 'nice', 'friendly', '2', 'pizza', 'ok'},
# 4: {'sauce', 'sure', 'meal', 'side', 'amazing', 'still', 'little', '3', 'definitely', 'bit', 'dinner', 'happy', 'salad', 'small', 'hot', 'location', 'something', 'love', 'everything', 'next', 'always', 'overall', 'eat', 'beer', 'table', 'lot', 'fries', '4', 'think', 'bar', 'pretty', 'lunch', 'excellent', 'cheese', 'best', 'though', 'tasty', 'delicious', 'drinks', 'area', 'menu', 'fried', 'try', 'nice', 'friendly', '2', 'pizza', 'atmosphere', 'enjoyed', 'fresh', 'recommend'},
# 5: {'sure', 'sauce', 'meal', 'amazing', 'every', 'many', 'little', 'definitely', 'say', 'clean', 'dinner', 'happy', 'awesome', 'love', 'everything', 'next', 'find', 'always', 'visit', 'coffee', 'years', 'looking', 'eat', 'super', 'ever', 'loved', 'highly', 'bar', 'lunch', 'excellent', 'spot', 'wonderful', 'cheese', 'family', 'best', 'work', 'favorite', 'delicious', 'feel', 'area', 'menu', 'worth', 'home', 'try', 'nice', 'friendly', 'perfect', 'pizza', 'atmosphere', 'fresh', 'recommend'}}
#
# Among top 500
# {1: {'immediately', 'literally', 'counter', '9', 'morning', 'number', 'treated', 'customers', 'disgusting', 'answer', 'month', 'insurance', 'website', 'seem', 'completely', 'calls', 'card', 'slow', 'believe', 'rather', 'dry', 'sales', 'charge', 'life', 'cost', 'placed', 'change', 'waited', 'sitting', 'horrible', 'already', 'reason', 'owner', 'mind', 'lost', 'expect', 'purchased', 'unprofessional', 'dirty', 'turned', 'explained', 'issues', 'paid', 'ready', 'sign', 'talk', 'credit', 'hope', 'lack', 'closed', 'needs', 'worse', 'run', 'move', 'zero', 'taken', 'guys', 'understand', 'speak', 'offered', 'show', 'hair', 'delivery', 'longer', 'ordering', 'save', 'management', 'maybe', 'received', 'stated', 'email', 'nail', 'fact', 'heard', 'returned', 'due', 'situation', 'seen', 'charged', 'instead', 'fix', 'kept', 'refused', 'anyone', 'ago', 'bill', 'oil', '8', 'bartender', 'taking', 'later', 'leave', 'seemed', 'orders', '45', 'mins', 'manager', 'talking', 'truck', 'call', 'nails', '7', 'gone', 'floor', 'buy', 'leaving', 'behind', 'spent', 'ok', 'sent', 'help', 'phone', 'changed', 'dog', 'absolutely', 'establishment', 'spoke', 'attitude', 'either', 'send', 'desk', 'knew', 'late', 'showed', 'weeks', 'ended', 'guess', 'months', 'sad', 'disappointing', 'sat', 'elsewhere', 'employee', 'waste', 'company', '50', 'okay', 'girl', 'min', 'total', 'please', 'telling', '40', 'checked', 'given', 'office', 'entire', 'issue', 'worst', 'contact', 'reservation', 'somewhere', 'sorry', '12', 'paying', 'rude', 'twice', 'pay', 'avoid', 'supposed', '15', 'unfortunately', 'poor', 'lady', 'problem', 'says', 'man', 'tip', 'vehicle', 'appointment', 'guy', 'woman', 'employees', 'awful', 'refund', 'response', 'asking', 'read', 'mistake', 'hold', 'multiple', 'fine', 'dollars', 'cold', 'seated', 'expensive', 'giving', 'moved', 'online', 'yelp', 'available', 'terrible', 'happened', 'set', 'empty', 'hear', 'minute', 'saying', 'clearly', '25', 'bought', '00', 'money'},
# 2: {'bacon', 'liked', 'counter', 'literally', 'spicy', 'morning', 'quick', 'local', 'customers', 'seem', '9', 'completely', 'card', 'slow', 'huge', 'dishes', 'rather', 'believe', 'dry', 'based', 'town', 'charge', 'cost', 'waited', 'sitting', 'reason', 'already', 'horrible', 'change', 'owner', 'chips', 'dessert', 'expect', 'appetizer', 'crab', 'quickly', 'dirty', 'red', 'paid', 'ate', 'ready', 'serve', 'hope', 'lack', 'soup', 'needs', 'run', 'servers', 'delicious', 'favorite', 'plus', 'cheap', 'main', 'cream', 'understand', 'white', 'offered', 'show', 'hair', 'enjoy', 'egg', 'delivery', 'longer', 'dining', 'ordering', '00', 'amazing', 'management', 'maybe', 'might', 'overpriced', 'received', 'hostess', 'fact', 'pasta', 'heard', 'bowl', 'due', 'rest', 'warm', 'honestly', 'charged', 'cake', 'instead', 'kept', 'noticed', 'saturday', 'sweet', 'spot', 'wine', 'selection', 'ago', 'anyone', 'bill', '8', 'bartender', 'taking', 'later', 'seemed', 'leave', 'orders', '45', 'manager', 'pieces', 'call', 'floor', '7', 'gone', 'nails', 'buy', 'behind', 'tacos', 'help', 'phone', 'ok', 'quite', 'dog', 'absolutely', 'beans', 'breakfast', 'wings', 'either', 'desk', 'late', 'city', 'ended', 'guess', 'months', 'roll', 'size', 'sad', 'overall', 'music', 'disappointing', 'although', 'sat', '50', 'rolls', 'restaurants', 'okay', 'girl', 'please', 'cool', 'average', 'real', 'potatoes', 'mexican', 'mind', 'given', 'entire', 'issue', 'worst', 'medium', 'impressed', 'barely', 'expected', 'atmosphere', 'sorry', 'fish', '12', 'paying', 'rude', 'regular', 'eggs', 'twice', 'pay', 'excited', '15', 'unfortunately', 'poor', 'lady', 'problem', 'loud', 'usually', 'tip', 'stuff', 'guy', 'appointment', 'employees', 'decent', 'awful', 'glass', 'fine', 'expensive', 'cold', 'seated', 'giving', 'salty', 'fast', 'tasty', 'seems', 'tea', 'bland', 'terrible', 'happened', 'set', 'empty', 'saying', 'beef', 'pork', 'mediocre', 'options', 'money'},
# 3: {'bacon', 'liked', 'spicy', 'counter', 'appetizers', 'quick', 'local', 'customers', 'seem', 'others', 'standard', 'slow', 'huge', 'dishes', 'rather', 'green', 'dry', 'based', 'town', 'grilled', 'waited', 'lots', 'reason', 'dessert', 'mind', 'sitting', 'already', 'chips', 'expect', 'crab', 'appetizer', 'quickly', 'style', 'mediocre', 'red', 'paid', 'ate', 'ready', 'serve', 'loved', 'fan', 'taco', 'soup', 'needs', 'attentive', 'servers', 'delicious', 'seating', 'favorite', 'plus', 'main', 'cheap', 'variety', 'cream', 'understand', 'add', 'brunch', 'white', 'offered', 'enjoy', 'space', 'egg', 'enjoyed', 'dining', 'ordering', 'hit', 'amazing', 'easy', 'maybe', 'might', 'fact', 'interesting', 'philly', 'pasta', 'heard', 'bowl', 'due', 'warm', 'portions', 'sometimes', 'option', 'pricey', 'mac', 'french', 'cake', 'instead', 'potato', 'choice', 'saturday', 'plenty', 'sweet', 'spot', 'thai', 'salsa', 'wine', 'selection', 'beers', 'ago', 'burgers', 'bill', '8', 'bartender', 'later', 'seemed', 'leave', 'orders', 'manager', 'call', 'floor', '7', 'flavors', 'tacos', 'ok', 'makes', 'help', 'chocolate', 'quite', 'beans', 'breakfast', 'wings', 'either', 'gets', 'late', 'city', 'crowded', 'ended', 'guess', 'seafood', 'roll', 'size', 'overall', 'music', 'although', 'disappointing', 'sides', 'sat', 'excellent', 'rolls', '50', 'restaurants', 'okay', 'fun', 'miss', 'early', 'decor', 'portion', 'cool', 'average', 'potatoes', 'real', 'mexican', 'perfect', 'given', 'issue', 'expected', 'impressed', 'often', 'fish', 'near', 'regular', 'rude', 'eggs', 'pay', 'excited', '15', 'unfortunately', 'awesome', 'sandwiches', 'problem', 'priced', 'loud', 'solid', 'usually', 'tip', 'stuff', 'guy', 'four', 'employees', 'decent', 'list', 'butter', 'fine', 'expensive', 'cold', 'seated', 'salty', 'fast', 'helpful', 'tasty', 'seems', 'tea', 'bbq', 'yelp', 'available', 'bland', 'set', 'beef', 'pork', 'sunday', 'atmosphere', 'etc', 'options', 'money'},
# 4: {'bacon', 'liked', 'spicy', 'counter', 'outdoor', 'quick', 'local', 'others', 'seem', 'slow', 'huge', 'dishes', 'green', 'italian', 'dry', 'town', 'grilled', 'lots', 'reason', 'dessert', 'mind', 'owner', 'chips', 'expect', 'crab', 'quickly', 'appetizer', 'style', 'beautiful', 'red', 'evening', 'ate', 'serve', 'loved', 'fan', 'surprised', 'soup', 'wonderful', 'attentive', 'favorite', 'delicious', 'seating', 'plus', 'variety', 'cheap', 'main', 'cream', 'sausage', 'add', 'brunch', 'white', 'show', 'orleans', 'enjoy', 'perfectly', 'space', 'enjoyed', 'egg', 'dining', 'chinese', 'ordering', 'hit', 'glad', 'amazing', 'specials', 'easy', 'maybe', 'might', 'fact', 'interesting', 'philly', 'pasta', 'bowl', 'warm', 'portions', 'sometimes', 'option', 'cute', 'mac', 'pricey', 'french', 'cake', 'instead', 'bite', 'tender', 'potato', 'reasonable', 'saturday', 'choice', 'plenty', 'sweet', 'spot', 'thai', 'salsa', 'wine', 'selection', 'beers', 'burgers', '8', 'flavorful', 'light', 'seemed', '7', 'flavors', 'tacos', 'chocolate', 'makes', 'ok', 'quite', 'dog', 'soon', 'absolutely', 'prepared', 'beans', 'breakfast', 'wings', 'located', 'either', 'crispy', 'gets', 'late', 'yummy', 'fantastic', 'trip', 'city', 'crowded', 'ended', 'seafood', 'roll', 'size', 'overall', 'music', 'along', 'although', 'sides', 'sat', 'neighborhood', 'highly', 'garlic', 'excellent', 'rolls', '50', 'restaurants', 'fun', 'date', 'ambiance', 'early', 'decor', 'portion', 'cool', 'perfect', 'real', 'mexican', 'potatoes', 'friday', 'impressed', 'often', 'unique', 'fish', 'patio', 'regular', 'downtown', 'eggs', 'pay', '15', 'sandwiches', 'awesome', 'packed', 'solid', 'priced', 'comfortable', 'loud', 'usually', 'st', 'pleasant', 'stuff', 'park', 'four', 'decent', 'list', 'oysters', 'butter', 'fine', 'expensive', 'seated', 'cold', 'fast', 'helpful', 'tasty', 'bbq', 'tea', 'seems', 'choose', 'yelp', 'available', 'beef', 'weekend', 'pork', 'sunday', 'authentic', 'atmosphere', 'etc', 'options'},
# 5: {'bacon', 'immediately', 'team', 'liked', 'spicy', 'morning', 'quick', 'local', 'dr', 'customers', 'huge', 'dishes', 'green', 'italian', 'reno', 'town', 'grilled', 'life', 'lots', 'dessert', 'already', 'owner', 'chips', 'crab', 'quickly', 'appetizer', 'beautiful', 'style', 'red', 'accommodating', 'evening', 'ready', 'ate', 'loved', 'forward', 'fan', 'soup', 'needs', 'wonderful', 'run', 'attentive', 'favorite', 'delicious', 'seating', 'visiting', 'plus', 'variety', 'knowledgeable', 'cream', 'guys', 'vegan', 'brunch', 'show', 'hair', 'orleans', 'enjoy', 'perfectly', 'space', 'enjoyed', 'world', 'dining', 'thanks', 'glad', 'amazing', 'easy', 'might', 'incredible', 'philly', 'nashville', 'pasta', 'bowl', 'warm', 'portions', 'outstanding', 'seen', 'questions', 'cute', 'mac', 'french', 'cake', 'birthday', 'bite', 'tender', 'potato', 'reasonable', 'choice', 'saturday', 'plenty', 'sweet', 'spot', 'helped', 'thai', 'wine', 'selection', 'anyone', 'ago', 'flavorful', 'light', 'later', 'leave', 'manager', 'call', 'flavors', 'buy', 'chocolate', 'tacos', 'makes', 'help', 'wow', 'quite', 'dog', 'soon', 'absolutely', 'prepared', 'beans', 'breakfast', 'lovely', 'wings', 'within', 'crispy', 'gets', 'knew', 'yummy', 'fantastic', 'trip', 'city', 'salon', 'wedding', 'seafood', 'months', 'roll', 'size', 'music', 'overall', 'thank', 'along', 'highly', 'excellent', 'company', 'rolls', 'restaurants', 'exactly', 'gem', 'fun', 'early', 'decor', 'cool', 'perfect', 'real', 'mexican', 'process', 'office', 'entire', 'impressed', 'unique', 'often', 'fish', 'tour', 'regular', 'worked', 'recommended', 'ingredients', 'professional', 'sandwiches', 'awesome', 'recently', 'priced', 'comfortable', 'usually', 'st', 'pleasant', 'tampa', 'stuff', 'appointment', 'fabulous', 'park', 'welcoming', 'guy', 'list', 'hands', 'across', 'moved', 'fast', 'helpful', 'tasty', 'beyond', 'tea', 'bbq', 'truly', 'yelp', 'choose', 'chef', 'available', 'set', 'beef', 'daughter', 'weekend', 'pork', 'authentic', 'sunday', 'atmosphere', 'etc', 'options'}}
#
# Among top 1000
# {1: {'threw', 'tires', 'disgusting', 'basically', '000', 'realized', 'none', 'slow', 'apartment', 'horrible', 'explained', 'warranty', 'talked', 'request', 'works', 'cook', 'zero', 'plan', 'package', 'crap', 'stating', 'word', 'dont', 'gift', 'quote', 'text', 'monday', 'bathroom', 'hostess', 'sick', 'situation', 'happen', 'true', 'complete', 'follow', 'putting', 'helped', 'provided', 'poorly', 'normal', 'furniture', 'schedule', 'machine', 'eyes', 'sent', 'mother', 'sucks', 'bottom', 'owners', 'groupon', 'send', 'knows', 'showed', 'handle', 'fixed', 'wedding', 'wash', 'trust', 'double', 'elsewhere', 'tiny', 'waste', 'nasty', 'smell', 'experienced', 'agreed', 'cars', 'state', 'feet', 'provide', 'sorry', 'rude', 'dead', 'professional', 'personal', 'picture', 'vehicle', 'replaced', 'woman', 'awful', 'ten', 'charges', 'bag', '11', 'women', 'bland', 'saying', 'deliver', 'trash', 'pass', 'u', '00', 'treated', 'answer', 'website', 'rent', 'rating', 'purchase', 'sales', 'driver', 'favor', 'lack', 'pictures', 'worse', 'forgot', 'nearly', 'per', 'speak', 'original', 'patient', 'pm', 'assured', 'save', '60', 'dealership', 'stated', 'bed', 'email', 'obviously', 'gel', 'delivered', 'frozen', 'informed', 'support', 'notice', 'cause', 'update', 'unit', 'polish', 'app', 'broken', 'didnt', 'shower', 'receive', 'bill', 'cleaned', 'covered', 'paper', 'truck', 'leaving', 'stood', 'wow', 'suggest', 'spoke', 'mail', 'attitude', 'salt', 'soggy', '18', 'tech', 'forever', 'fee', 'drove', 'sad', 'discount', 'disappointing', 'general', 'began', 'company', 'okay', 'absolute', 'security', 'total', 'hung', 'telling', 'repair', 'moving', 'average', 'worst', 'barely', 'somewhere', 'ignored', 'paying', 'unfortunately', 'loud', 'dark', 'considering', 'figured', 'mention', 'response', 'asking', 'hold', 'post', 'replace', 'ruined', 'positive', 'beyond', 'doctor', 'whatever', 'happened', 'apology', 'empty', 'system', 'except', 'unacceptable', 'contract', 'mediocre', 'write', 'member', 'checking', 'treatment', 'cashier', 'using', 'calls', 'card', 'sell', 'everywhere', 'cover', 'sold', 'buying', 'disappointment', 'lost', 'answered', 'purchased', 'dirty', 'figure', 'massage', 'sale', 'filthy', 'property', 'requested', 'scam', 'prior', 'management', 'health', 'gross', 'book', 'scheduled', 'dropped', 'matter', 'charged', 'miles', 'story', 'contacted', 'air', 'mins', 'actual', '100', 'nails', 'thru', 'spent', 'test', 'straight', 'turn', 'salon', 'living', 'maintenance', 'thank', 'address', 'school', 'rate', 'mentioned', 'son', 'mess', 'excuse', 'joke', 'min', 'brand', 'treat', 'willing', 'doors', 'contact', 'properly', 'dollar', '0', 'supposed', 'following', 'appointment', 'single', 'tells', 'toilet', 'message', 'costs', 'burnt', 'services', 'problems', 'shame', 'alone', 'previous', 'clearly', 'information', 'complained', 'question', 'returned', 'insurance', 'dr', 'damage', 'complaint', 'account', 'bank', 'communication', 'placed', 'means', 'cannot', 'hate', 'unprofessional', 'ridiculous', 'credit', 'sense', 'workers', 'cleaning', 'policy', 'move', 'correct', 'explain', 'apologized', 'eye', 'thanks', 'register', 'unless', 'overpriced', 'nail', 'possible', 'wearing', 'attention', 'questions', 'pool', 'department', 'fix', 'allowed', 'third', 'refused', 'nobody', 'airport', 'rental', 'interested', 'arrive', 'receipt', 'incredibly', '45', 'dress', 'talking', 'dogs', 'pain', 'closing', 'promised', 'cancel', 'break', 'complain', 'proceeded', 'calling', 'ran', 'event', 'pedicure', 'booked', '24', 'seat', 'apparently', 'anyway', 'mask', 'guess', 'parts', 'product', 'experiences', 'garbage', 'employee', 'yesterday', 'returning', 'lettuce', 'guests', 'tire', 'covid', 'driving', 'clear', 'additional', 'face', 'deposit', 'thinking', 'process', '40', 'sister', 'fault', 'standing', 'continued', 'avoid', 'poor', 'bother', 'says', 'anymore', 'hands', 'refund', 'upset', 'mistake', 'color', 'broke', 'missing', 'negative', 'dollars', 'beware', 'truly', 'terrible', '35', 'hell', 'stuck', ' ...
# 2: {'tough', 'locations', 'basically', 'standard', 'disgusting', 'realized', 'none', 'slow', 'toast', 'slightly', 'horrible', 'style', 'beautiful', 'explained', 'greasy', 'request', 'wonderful', 'diner', 'attentive', 'cook', 'seating', 'thin', 'word', 'chinese', 'bathroom', 'hostess', 'situation', 'happen', 'cute', 'complete', 'pricey', 'bottle', 'club', 'plenty', 'chain', 'selection', 'normal', 'fairly', 'overcooked', 'flavors', 'sent', 'bottom', 'owners', 'soft', 'send', 'certainly', 'level', 'showed', 'crowded', 'sour', 'wash', 'value', 'elsewhere', 'tiny', 'waste', 'excellent', 'otherwise', 'thick', 'smell', 'experienced', 'ambiance', 'boy', 'expecting', 'portion', 'girls', 'folks', 'impressed', 'sorry', 'gravy', 'rude', 'pleasant', 'reading', 'difficult', 'meh', 'woman', 'awful', 'lacking', 'mostly', 'bag', '11', 'bbq', 'bland', 'saying', 'lacked', 'pass', '00', 'dip', 'lobster', 'liked', 'spicy', 'appetizers', 'corner', 'answer', 'treated', 'website', 'rating', 'ribs', 'grilled', 'loved', 'lack', 'rushed', 'patrons', 'forgot', 'worse', 'stale', 'veggies', 'nearly', 'per', 'speak', 'original', 'chose', 'pm', 'annoyed', 'save', 'tomato', 'easy', 'bed', 'obviously', 'kinda', 'interesting', 'delivered', 'nashville', 'frozen', 'informed', 'tv', 'notice', 'update', 'potato', 'vegetables', 'salsa', 'thai', 'beers', 'receive', 'bill', 'burgers', 'cleaned', 'opinion', 'covered', 'paper', 'leaving', 'stood', 'chocolate', 'donuts', 'attitude', 'salt', 'soggy', 'uncomfortable', 'forever', 'fee', 'crust', 'sad', 'grab', 'dressing', 'shot', 'disappointing', 'flavorless', 'pie', 'garlic', 'general', 'company', 'pho', 'okay', 'fun', 'limited', 'total', 'seasoned', 'movie', 'telling', 'buffet', 'average', 'worst', 'barely', 'somewhere', 'paying', 'mixed', 'downtown', 'unfortunately', 'packed', 'loud', 'dark', 'salmon', 'considering', 'figured', 'mention', 'included', 'asking', 'response', 'hold', 'broth', 'raw', 'crowd', 'positive', 'whatever', 'happened', 'empty', 'system', 'except', 'sort', 'mediocre', 'write', 'seats', 'toppings', 'cashier', 'using', 'card', 'odd', 'lots', 'dessert', 'disappointment', 'lost', 'salads', 'perhaps', 'dirty', 'surprised', 'chewy', 'massage', 'tastes', 'delicious', 'sausage', 'slices', 'world', 'enjoyed', 'requested', 'mall', 'management', 'slice', 'gross', 'tuna', 'sometimes', 'view', 'dropped', 'matter', 'mac', 'charged', 'onions', 'texture', 'flavorful', 'mins', 'seeing', 'actual', 'higher', '100', 'nails', 'thru', 'spent', 'seasoning', 'joint', 'corn', 'normally', 'crispy', 'tasteless', 'turn', 'salon', 'strange', 'baked', 'thank', 'mentioned', 'son', 'mess', 'min', 'miss', 'hoping', 'perfect', 'choices', 'pepper', 'properly', 'supposed', 'ingredients', 'sandwiches', 'comfortable', 'appointment', 'single', 'expectations', 'oysters', 'butter', 'weird', 'burnt', 'salty', 'problems', 'onion', 'tasty', 'shame', 'needless', 'choose', 'previous', 'clearly', 'basic', 'chili', 'smaller', 'returned', 'la', 'soda', 'refill', 'green', 'italian', 'stick', 'placed', 'means', 'cannot', 'hate', 'ridiculous', 'fan', 'credit', 'workers', 'cleaning', 'cocktail', 'move', 'visiting', 'calamari', 'brown', 'flat', 'brunch', 'par', 'typical', 'correct', 'space', 'apologized', 'tasting', 'eye', 'thanks', 'register', 'unless', '14', 'overpriced', 'fruit', 'nail', 'possible', 'attention', 'portions', 'questions', 'french', 'pool', 'plastic', 'sadly', 'fix', 'third', 'airport', 'arrive', 'receipt', 'incredibly', 'imagine', '45', 'fair', 'talking', 'sub', 'menus', 'blue', 'break', 'complain', 'ran', 'rare', 'pedicure', 'burrito', 'game', 'seat', 'anyway', 'apparently', 'plain', 'guess', 'experiences', 'product', 'feeling', 'sides', 'employee', 'yesterday', 'returning', 'lettuce', 'guests', 'exactly', 'clear', 'decor', 'face', 'rush', 'thinking', 'process', '40', 'chairs', 'standing', 'patio', 'avoid', 'bother', 'poor', 'awesome', 'says', 'heat', 'anymore', 'bun', 'grill', 'hands', 'mistake', 'color', 'missing', 'dollars', 'entree ...
# ...
# 3: {'argue', 'array', 'sketchy', 'moderate', 'flavoring', 'freeway', 'cranberry', 'pizzeria', 'lift', 'exceptionally', 'legacy', 'comped', 'instance', 'addressed', 'casserole', 'sicilian', 'peak', 'featured', 'huevos', 'judging', '10pm', 'sips', 'collard', 'fear', 'fillings', 'pleasantly', 'penn', 'asada', 'rows', 'trek', 'dust', 'competitive', 'eclectic', 'maple', 'tikka', 'compensate', 'stools', 'easter', 'opt', 'depends', 'turtle', 'whipped', 'steer', 'celery', 'rittenhouse', 'watering', 'mediterranean', 'jamaican', 'stack', 'requires', 'hyped', 'aquarium', 'poorly', 'wraps', 'substantial', 'slide', 'stellar', 'undercooked', 'replied', 'fu', 'overcooked', 'trade', 'buffets', 'batch', 'sunny', 'deciding', 'rainy', 'visible', 'alligator', 'acoustics', 'margherita', 'feature', 'extras', 'mash', 'tater', 'uninspired', 'scale', 'awkwardly', 'stacked', 'professionalism', 'confit', 'digress', 'remain', 'ayce', 'singer', 'activities', 'born', 'trio', 'soap', 'chunky', 'punch', 'accompanying', 'croutons', 'sweetened', 'picnic', 'staring', 'palace', 'metairie', 'historic', 'karaoke', 'acceptable', 'apologetic', 'fennel', 'pepsi', 'profit', 'clueless', 'compete', 'hence', 'cheerful', 'bang', 'bao', 'clearance', 'dave', 'cereal', 'hallway', 'charming', 'error', 'blend', 'birds', 'mystery', 'heaven', 'loving', 'plentiful', 'caution', 'incorrect', 'dill', 'extraordinary', 'generously', 'attractive', 'pier', 'basics', 'thirsty', 'proximity', 'skimp', 'delaware', 'enthusiastic', 'carts', 'benny', 'spin', 'tear', 'cauliflower', 'pastas', 'anybody', 'dd', 'stale', 'dense', 'scallion', 'avenue', 'eater', 'naked', 'airy', 'fixing', 'annoyed', 'cupcake', 'mex', 'pecan', 'runner', 'extreme', 'apples', 'infused', 'sampling', 'boneless', 'outdated', 'denny', 'communicate', 'separated', 'cozy', 'silly', 'spit', 'samosa', 'kudos', 'killed', 'luster', 'positives', 'wander', 'smiled', 'cardboard', 'ole', 'sorts', 'someplace', 'italy', 'stressed', 'satisfy', 'rustic', 'tartare', 'hookah', 'surly', 'ybor', 'byo', 'mt', 'americanized', 'ihop', 'tongue', 'lackluster', 'herb', 'wind', 'entrée', 'buzz', 'explore', 'condescending', 'er', 'rid', 'romaine', 'craft', 'instant', 'streets', 'robin', 'backed', 'cow', 'nutella', 'amazingly', 'varieties', 'poboy', 'pastor', 'tipped', 'gourmet', 'caliber', 'indoors', 'reminiscent', 'bustling', 'charging', 'bachelorette', 'stared', 'ripe', 'garnish', 'fits', '150', 'crabs', 'runny', 'grumpy', 'answering', 'chalk', 'jalapeños', 'contrast', 'pate', 'blah', 'huh', 'saucy', 'presence', 'frills', 'artificial', 'slab', 'twist', 'lover', 'unfriendly', 'em', 'tilapia', 'tower', 'touristy', 'rudely', 'motel', 'refried', 'smokey', 'evenings', 'thicker', 'separately', 'specially', 'marsala', 'appetizing', 'boil', 'fishy', 'unreasonable', 'rabe', 'bizarre', 'wontons', 'exhibit', 'rubbery', 'supreme', '2019', 'swiss', 'heavily', 'tamale', 'rye', 'mixing', 'wound', 'napkin', 'cigarette', 'okra', 'downfall', 'stare', 'gooey', 'burning', 'raving', 'nine', 'hh', 'boo', 'sufficient', 'panini', 'décor', 'charm', 'servings', 'squeezed', 'circumstances', 'al', 'festive', 'largest', 'dated', 'unexpected', 'divey', 'acme', 'expectation', 'tastier', 'overheard', 'responded', 'yell', 'voice', 'enormous', 'wedge', '30am', 'magazine', 'rooftop', 'crackers', 'ahi', 'engaging', 'panera', 'chinatown', 'survive', 'lively', 'pricier', 'jumping', 'hearty', 'unremarkable', 'mole', 'cheesesteaks', 'hint', 'occupied', 'atop', 'hockey', 'hotter', 'opposed', 'rule', 'delightful', 'spirit', 'virtually', 'benches', 'carte', 'justify', 'trick', 'fig', 'vegetarians', 'jalapenos', 'jalapeño', 'hesitate', 'decorated', 'outdoors', 'props', 'covering', 'tab', 'oatmeal', 'lightly', 'struggle', 'dragon', 'ease', 'chunk', 'quaint', 'fryer', 'mart', 'improvements', 'piping', 'renovated', 'taps', 'yelper', 'tenderloin', 'sage', 'vast', 'clue', 'mug', 'scenery', 'ceilings', 'boutique', 'def', 'pedestrian', 'unprofessional', 'andouille', 'fl', 'seaweed', 'bones', 'hoste ...
# 4: {'array', 'sketchy', 'moderate', 'sauna', 'flavoring', 'cranberry', 'pizzeria', 'instance', 'melts', 'exceptionally', 'hong', 'casserole', 'peak', 'featured', 'huevos', 'judging', '10pm', 'revisit', 'collard', 'fear', 'fillings', 'pleasantly', 'penn', 'asada', 'trek', 'dust', 'competitive', 'eclectic', 'descriptions', 'maple', 'tikka', 'stools', 'carefully', 'easter', 'opt', 'depends', 'turtle', 'instructors', 'cuisines', 'pine', 'whipped', 'landed', 'steer', 'celery', 'rittenhouse', 'watering', 'mediterranean', 'jamaican', 'colleague', 'stack', 'maintain', 'biryani', 'vendor', 'rim', 'aquarium', 'poorly', 'wraps', 'substantial', 'slide', 'stellar', 'undercooked', 'replied', 'gracious', 'overcooked', 'buffets', 'batch', 'mule', 'sunny', 'rainy', 'deciding', 'alligator', 'acoustics', 'margherita', 'feature', 'churros', 'tunes', 'heights', 'mash', 'tater', 'scale', 'tandoori', 'confit', 'remain', 'matcha', 'darker', 'ayce', 'activities', 'born', 'trio', 'soap', 'chunky', 'punch', 'accompanying', 'croutons', 'picnic', 'warmly', 'individuals', 'historic', 'karaoke', 'acceptable', 'apologetic', 'fennel', 'nick', 'accident', 'hence', 'cheerful', 'bang', 'bao', 'hotdog', 'thursdays', 'clearance', 'dave', 'cereal', 'hallway', 'david', 'attack', 'charming', 'portioned', 'blend', 'mystery', 'heaven', 'loving', 'canadian', 'customize', 'anticipated', 'plentiful', 'worthwhile', 'dill', 'et', 'extraordinary', 'generously', 'interactive', 'attractive', 'pier', 'basics', 'wins', 'proximity', 'skimp', 'delaware', 'enthusiastic', 'carts', 'hiking', 'benny', 'spin', 'cauliflower', 'pastas', 'genuine', 'stale', 'dense', 'scallion', 'korma', 'avenue', 'eater', 'naked', 'scrapple', 'airy', 'police', 'annoyed', 'parks', 'cupcake', 'mex', 'plump', 'pecan', 'en', 'apples', 'infused', 'sampling', 'rounded', 'boneless', 'outdated', 'map', 'separated', 'cozy', 'silly', 'height', 'kudos', 'wander', 'chocolates', 'enjoys', 'ole', 'sorts', 'someplace', 'italy', 'satisfy', 'rustic', 'byo', 'ybor', 'tartare', 'hookah', 'peppery', 'treasure', 'americanized', 'bursting', 'ihop', 'tongue', 'lackluster', 'herb', 'pb', 'wind', 'entrée', 'buzz', 'dutch', 'fabric', 'kong', 'explore', 'romaine', 'rid', 'craft', 'streets', 'backed', 'featuring', 'cow', 'vibrant', 'vote', 'nutella', 'handmade', 'amazingly', 'playground', 'varieties', 'pastor', 'poboy', 'gourmet', 'indoors', 'reminiscent', 'bustling', 'charging', 'tiger', 'artists', 'conscious', 'madness', 'winery', 'fits', '150', 'crabs', 'runny', 'plethora', 'chalk', 'jalapeños', 'contrast', 'blah', 'halibut', 'succulent', 'diamond', 'saucy', 'architecture', 'chester', 'frills', 'slab', 'cobbler', 'twist', 'guided', 'anthony', 'étouffée', 'lover', 'em', 'tilapia', 'tower', 'touristy', 'motel', 'refried', 'smokey', 'evenings', 'thicker', 'separately', 'marsala', 'bayou', 'taqueria', 'appetizing', 'boil', 'fishy', 'northeast', 'rabe', 'wontons', 'oscar', 'exhibit', 'rubbery', 'worries', 'exquisite', 'swiss', 'heavily', 'tamale', 'rye', 'mixing', 'attraction', 'wound', 'okra', 'legendary', 'downfall', 'brain', 'gooey', 'raving', 'mattress', 'hh', 'nine', 'ultimate', 'panini', 'décor', 'charm', 'squeezed', 'servings', 'institution', 'al', 'dente', 'largest', 'dated', 'cultural', 'unexpected', 'divey', 'acme', 'tastier', 'enormous', 'puff', 'sauerkraut', 'boozy', 'wedge', 'thoughtful', 'frames', 'peaches', 'magazine', 'exam', 'rooftop', 'crackers', 'ahi', 'engaging', 'panera', 'chinatown', 'backyard', 'lively', 'pricier', 'hearty', 'mole', 'sausages', 'nostalgic', 'turkish', 'honeymoon', 'cheesesteaks', 'hint', 'occupied', 'hockey', 'atop', 'hotter', 'compliments', 'opposed', 'rule', 'delightful', 'spirit', 'benches', 'carte', 'monster', 'justify', 'trick', 'growler', 'rotate', 'studying', 'fig', 'vegetarians', 'jalapenos', 'jalapeño', 'quail', 'stress', 'mores', 'hesitate', 'decorated', 'preferences', 'outdoors', 'props', 'refilling', 'filipino', 'tab', 'oatmeal', 'lightly', 'dragon', 'ease', 'rigatoni', 'quaint', 'en ...
# 5: {'array', 'mrs', 'floats', 'compelled', 'cranberry', 'pizzeria', 'lift', 'exceptionally', 'melts', 'addressed', 'sicilian', 'peak', 'featured', 'huevos', 'collard', 'fear', 'fillings', 'pleasantly', 'riding', 'asada', 'trek', 'baking', 'competitive', 'eclectic', 'memphis', 'descriptions', 'maple', 'tikka', 'quotes', 'carefully', 'opt', 'instructors', 'turtle', 'whipped', 'celery', 'rittenhouse', 'watering', 'mediterranean', 'jamaican', 'haunted', 'emily', 'biryani', 'vendor', 'rim', 'removal', 'aquarium', 'wraps', 'parlor', 'substantial', 'serviced', 'stellar', 'gracious', 'trade', 'testing', 'rachel', 'sunny', 'rainy', 'deciding', 'mule', 'alligator', 'guaranteed', 'margherita', 'feature', 'churros', 'heights', 'plumbing', 'mash', 'tater', 'scale', 'professionalism', 'confit', 'matcha', 'ayce', 'floral', 'activities', 'born', 'cellar', 'trio', 'barbershop', 'chunky', 'punch', 'diagnosed', 'picnic', 'warmly', 'ink', 'palace', 'metairie', 'niece', 'historic', 'anna', 'karaoke', 'workouts', 'profit', 'nick', 'compete', 'accident', 'cheerful', 'bang', 'bao', 'dave', 'david', 'appliance', 'charming', 'portioned', 'blend', 'birds', 'heaven', 'loving', 'customize', 'anticipated', 'plentiful', 'dill', 'extraordinary', 'died', 'generously', 'interactive', 'attractive', 'pier', 'bday', 'surprises', 'delaware', 'skimp', 'enthusiastic', 'haircuts', 'elizabeth', 'luxurious', 'spin', 'cauliflower', 'pastas', 'anybody', 'genuine', 'windshield', 'taught', 'eater', 'avenue', 'airy', 'fixing', 'police', 'parks', 'cupcake', 'pecan', 'visual', 'susan', 'runner', 'en', 'extreme', 'apples', 'infused', 'sampling', 'rounded', 'barbers', 'map', 'communicate', 'cozy', 'silly', 'miami', 'towed', 'kudos', 'killed', 'wander', 'chocolates', 'enjoys', 'ole', 'sorts', 'italy', 'muscle', 'stressed', 'satisfy', 'rustic', 'byo', 'ybor', 'mt', 'tartare', 'woods', 'treasure', 'clinic', 'tongue', 'sunshine', 'megan', 'official', 'herb', 'wind', 'entrée', 'photography', 'dutch', 'fabric', 'smog', 'explore', 'er', 'romaine', 'craft', 'streets', 'owns', 'trainer', 'featuring', 'cow', 'vibrant', 'tremendously', 'deserved', 'nutella', 'handmade', 'amazingly', 'playground', 'varieties', 'pastor', 'poboy', 'gourmet', 'indoors', 'units', 'bachelorette', 'artists', 'conscious', 'winery', 'fits', 'crabs', 'plethora', 'answering', 'purse', 'jalapeños', 'halibut', 'succulent', 'gary', 'diamond', 'yrs', 'architecture', 'presence', 'frills', 'slab', 'cobbler', 'unreal', 'twist', 'guided', 'hygienist', 'anthony', 'lover', 'em', 'tower', 'touristy', 'laura', 'faith', 'smokey', 'outcome', 'evenings', 'missouri', 'daycare', 'ur', 'specially', 'shawn', 'boil', 'lox', 'charcoal', 'northeast', 'oscar', 'exhibit', 'jennifer', 'vets', 'andy', '2019', 'exquisite', 'swiss', 'tamale', 'rye', 'hardest', 'okra', 'tailor', 'brain', 'gooey', 'burning', 'raving', 'mattress', 'nine', 'ultimate', 'panini', 'designs', 'charm', 'squeezed', 'servings', 'institution', 'austin', 'bookstore', 'lick', 'al', 'katie', 'flawless', 'festive', 'largest', 'carpets', 'cultural', 'unexpected', 'tastier', 'responded', 'breathtaking', 'pregnant', 'enormous', 'voice', 'puff', 'mortgage', 'wedge', 'thoughtful', 'frames', 'cemetery', 'magazine', 'exam', 'rooftop', 'bow', 'ahi', 'engaging', 'backyard', 'chinatown', 'lively', 'pricier', 'hearty', 'mole', 'turkish', 'coloring', 'cheesesteaks', 'hint', 'graduation', 'compliments', 'opposed', 'delightful', 'cotton', 'spirit', 'eric', 'benches', 'compassion', 'carte', 'washer', 'monster', 'studying', 'fig', 'vegetarians', 'jalapenos', 'shock', 'officially', 'jalapeño', 'quail', 'stress', 'preferences', 'hesitate', 'decorated', 'award', 'outdoors', 'props', 'montecito', 'oatmeal', 'refer', 'lightly', 'christine', 'dragon', 'ease', 'pampered', 'quaint', 'heating', 'shaded', 'es', 'piping', 'renovated', 'taps', 'papa', 'boarding', 'tenderloin', 'installation', 'confident', 'vast', 'mug', 'tyler', 'scenery', 'marys', 'az', 'mouthwatering', 'treatments', 'ceilings', 'bouti ...

# %% [markdown]
# Explore the print output above as you see fit. In general, the most useful sets of words appear to be the truly unique words from settings at  n=100 on up.
#
# One issue with using the "truly unique" words is that, especially at 2- and 3-star ratings, there aren't very many of them.
#
# On the other hand, using the "not at every star rating" words results in many words in isolation that might have very different sentiment valence in-context: e.g., the positive word 'great' may appear often in 2-star reviews, but in negative phrases like "the food really wasn't great".
#
# In general, as one might expect, sentiment words at the 3-star range appear to be intermediary ("moderate", "decent") and words that don't fit a sentiment valence especially well. It does seems as though the especially negative words are much more prevalent at 2-star and below than they are at 3-star or above.

# %% [markdown]
# ### Notes / Directions for future analysis
#
# If I could do this over again / had more time at this stage of exploratory analysis, here are some more leads that I might pursue:
#
# * Create a longer and more detailed list of stopwords to eliminate things from Yelp review text that are unlikely to occur in tweets about the Affordable Care Act (e.g. the _many_ named foods, city names, common first names and surnames, occupation-specific words like "waitress"). This would get more sentiment-laden words about general customer reaction into the list of most common words, and make it easier to evaluate the data for sentiment at sight.<br><br>
# * Bag-of-words sentiment analysis on the groups of most common words by star rating -- this could produce a sentiment score that allowed for deciding a cutoff in a less subjective fashion (or, at least, in a fashion that outsources the subjective judgment to a robust, peer-approved software library)<br><br>
# * Plot the "n" for n most common words vs. how many words are unique to each star rating at that n (a different trendline for each star rating). It might be interesting to see if the trend is sublinear as a higher n means more common words overlap across the subsamples.

# %% [markdown]
# ### By-review sentiment analysis
#
# _The nltk library asks us to cite the following:_<br>
# Hutto, C.J. & Gilbert, E.E. (2014). VADER: A Parsimonious Rule-based Model for<br>
# Sentiment Analysis of Social Media Text. Eighth International Conference on<br>
# Weblogs and Social Media (ICWSM-14). Ann Arbor, MI, June 2014.

# %%
#Sources consulted:
#https://towardsdatascience.com/social-media-sentiment-analysis-in-python-with-vader-no-training-required-4bc6a21e87b8

#Call nltk.download('vader_lexicon') from python interpreter before running this
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sent_analyzer = SentimentIntensityAnalyzer()

#polarity_scores() creates a dictionary object with 'neg', 'neu', 'pos', and 
# 'compound' scores in it.
#For simplicity, using only the 'compound' score

for i, star_df in enumerate(star_dfs):
    star_df.loc[:,'vader_scores'] = star_df.loc[:,'text'].apply(lambda x: 
                                                           sent_analyzer.polarity_scores(x)['compound'])

# %% [markdown]
# By convention, VADER scores over 0.05 are treated as 'positive', under -0.05 as 'negative', and between -0.05 and 0.05 as 'neutral.'

# %%
vader_stats = pd.DataFrame()

for i, star_df in enumerate(star_dfs):
    vader_stats = pd.concat((vader_stats,
              star_df.loc[:,'vader_scores'].agg(['min', 'max', 'mean', 'median', 'std'])),
              axis=1)
vader_stats.columns = [f'{i}-star' for i in range(1,6)]

vader_stats
# Out:
#           1-star    2-star    3-star    4-star    5-star
# min    -0.998800 -0.996900 -0.993400 -0.984400 -0.980700
# max     0.999000  0.999200  0.999500  0.999800  0.999600
# mean   -0.200316  0.250146  0.618181  0.844875  0.880896
# median -0.433700  0.480300  0.860500  0.942300  0.949100
# std     0.678222  0.670057  0.509417  0.276096  0.214964

# %% [markdown]
# By the looks of it, only 1-star reviews have negative mean and/or median. This suggests that it may make sense to isolate 1-star reviews as 'negative' while counting all others as 'positive'. However, each star rating has a very high standard deviation for VADER score, and all star ratings have a median quite distinct from the mean, which suggests that plotting the shape of the data may provide additional insight. Let's do that.

# %%
#fig, ax = plt.subplots(sharex=True)

#ax = reviews_1star.plot.hist(column='vader_scores', alpha=0.5, color='red')
reviews_5star['vader_scores'].hist(alpha=0.5, color='blue', bins=100)
reviews_4star['vader_scores'].hist(alpha=0.6, color='green', bins=100)
reviews_3star['vader_scores'].hist(alpha=0.7, color='yellow', bins=100)
reviews_2star['vader_scores'].hist(alpha=0.8, color='orange', bins=100)
reviews_1star['vader_scores'].hist(alpha=0.6, color='red', bins=100)
# Out:
# <AxesSubplot: >

# %% [markdown]
# The weights seem very off here, with almost all ratings in the highly positive range. This suggests to me that maybe doing the compound polarity score separately on each star rating was skewing the results. So I tried it again, doing compound polarity score for the entire original reviews dataframe and then seeing if the distribution changed:

# %%
reviews.loc[:,'vader_scores'] = reviews.loc[:,'text'].apply(lambda x: 
                                                            sent_analyzer.polarity_scores(x)['compound'])

# %%
reviews.loc[(reviews.loc[:,'stars']==5),'vader_scores'].hist(alpha=0.5, color='blue', bins=100)
reviews.loc[(reviews.loc[:,'stars']==4),'vader_scores'].hist(alpha=0.6, color='green', bins=100)
reviews.loc[(reviews.loc[:,'stars']==3),'vader_scores'].hist(alpha=0.7, color='yellow', bins=100)
reviews.loc[(reviews.loc[:,'stars']==2),'vader_scores'].hist(alpha=0.8, color='orange', bins=100)
reviews.loc[(reviews.loc[:,'stars']==1),'vader_scores'].hist(alpha=0.6, color='red', bins=100)
# Out:
# <AxesSubplot: >

# %% [markdown]
# It didn't.
#
# The pattern for all ratings above 1 is a sharp left-skew (large peak on right end of distribution), whereas the pattern for 1-star reviews has a modest right-skew (small peak on left end). The peak for 2-star reviews, however, is substantially lower than the peaks for 3 to 5 stars, and both 2-star and 1-star reviews have some noticeable number of reviews along the entire gamut from -1.00 to 1.00.

# %% [markdown]
# ### Notes / directions for future analysis

# %% [markdown]
# * Analyze how the VADER compound polarity scores work, to see why they're so skewed for this data set / figure out how "train" VADER so Yelp review scores aren't tilted so far towards extreme scores<br><br>
# * Plot negative, positve, and neutral VADER score components on separate charts, to see if the scores underlying the compound number have their own interesting trends that don't show up in the compound score data

# %% [markdown]
# ## Recommendation
#
# If we were looking at things from a merely statistical standpoint using the VADER compound score, it might make sense to set the cutoff between 1-star and 1-star. However, the assessment of common words for the 2-star reviews brings up a lot of intensely negative terms, such as (to look at truly unique words in the 1000 most common) 'flavorless', 'rushed', 'raw', 'stale', 'tasteless', 'uncomfortable', and 'annoyed.' I don't want to discount that impression.
#
# Therefore: My <u>official recommendation</u> is that, for the remainder of this project, we classify **Yelp reviews with _3 or more stars_ as "positive" $(label = 1)$**, and **all others (1 or 2 stars) as "negative" $(label=0)$**, with **no "neutral" category**. This will capture the sharp jump in positivity scores at the 3-star level and the subjective assessment that 2-star reviews have significantly more negative terms even if the naive settings for VADER didn't recognize them as such. It will also enable us to use binary classification methods, which build most directly on the course material covered thus far.
#
# As we proceed, though, we should keep in mind that the Yelp star reviews are a rather messy, lossy measure (which makes sense, as different users don't have to follow the same standards when deciding how to review an establishment), and simplifying them to a binary classification introduces even more mess and loss. Some of our labels may strike us "incorrect" or "misleading" in ways that we can't really adjust going forward. As such, we shouldn't be surprised if it is difficult to obtain high accuracy in classification models.
